# %%
import pandas as pd
import re                                   # регулярные выражениями
import numpy as np
from nltk.stem.porter import PorterStemmer  # стеммер
import nltk                               # работа с естественным языком           
from nltk.corpus import stopwords         # список стоп-слов
import string                             # работа со строковыми значениями
from sklearn.feature_extraction.text import TfidfVectorizer          # Преобразование тектов в TFIDF-матрицу
from sklearn.metrics.pairwise import cosine_similarity               # Метрика измерения косинусного расстояния между векторами
import gensim                                        # Работа с моделями W2V
import gensim.downloader
from gensim.models import word2vec,KeyedVectors

# %%
# Загрузим данные
df = pd.read_csv('sample-data.csv')

# Сводная информация о загруженном датасете
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           500 non-null    int64
#  1   description  500 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 7.9+ KB

# %%
#Стеммер
stemmer = PorterStemmer()

# %%
import nltk
nltk.download('stopwords')
# Справочник английских стоп-слов 
stopwords_english = stopwords.words('english')

# Список стоп-слов
print('Базовый список стоп-слов:', stopwords_english)
# Out:
# Базовый список стоп-слов: ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\a_l_b\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Работа по преобразованию данных в нужный вид.
class dataset():
    def __init__(self, df):
        self.df = df
        self.spec_chars_ = string.punctuation
        self.stopwords_english = stopwords.words('english')
     #Функция удаления символов из текста
    def remove_chars_from_text(self, text_, chars_):
            return "".join([ch for ch in text_ if ch not in chars_])
    # Функция удаления HTML-ссылок
    def remove_urls(self, text_):
        url_remove = re.compile(r'https?://\S+|www\.\S+')
        return url_remove.sub(r' ', str(text_))
    # Функция удаления URL-ссылок
    def remove_html(self, text_):
        html=re.compile(r'<.*?>')
        return html.sub(r' ',str(text_))
    # Функция удаления стоп-слов
    def clear_stop_words(self, text_):
        return ' '.join([word for word in str(text_).split() if word not in stopwords_english])
 
    def forward(self, df):
        # Удаляем URL-ссылки
        df["description"] = df["description"].apply(lambda x: self.remove_urls(str(x)))
        # Удаляем HTML-ссылки
        df["description"] = df["description"].apply(lambda x: self.remove_html(str(x)))
        # Переводим символы к нижнему регистру
        df["description"] = df["description"].apply(lambda x: x.lower())
        # Удаляем пунктуацию и спец-символы
        df["description"] = df["description"].apply(lambda x: self.remove_chars_from_text(str(x), self.spec_chars_))
        # Удаляем цифры
        df["description"] = df["description"].apply(lambda x: self.remove_chars_from_text(str(x), string.digits))
        # Убираем лишние пробелы
        df["description"] = df["description"].apply(lambda x: ' '.join(x.split()))
        # Убираем стоп-слова
        df["description"] = df["description"].apply(lambda x: self.clear_stop_words(x))
        # Stemmer
        df["description"] = df["description"].apply(lambda x: " ".join([stemmer.stem(word) for word in x.split()]))
        return df

# %%
d = dataset(df)

# %%
data = pd.DataFrame(d.forward(df))

# %%
data
# Out:
#       id                                        description
# 0      1  activ classic boxer there reason boxer cult fa...
# 1      2  activ sport boxer brief skin glori requir enou...
# 2      3  activ sport brief superbreath nofli brief mini...
# 3      4  alpin guid pant skin climb ice switch rock tra...
# 4      5  alpin wind jkt high ridg steep ice anyth alpin...
# ..   ...                                                ...
# 495  496  cap bottom cut loos madden crowd search undon ...
# 496  497  cap crew crew take edg fickl weather clear con...
# 497  498  alltim shell need use morn time umbrella allti...
# 498  499  allwear cargo short allwear cargo short bask g...
# 499  500  allwear short time simplifi allwear short prov...
#
# [500 rows x 2 columns]

# %% [markdown]
# # Вариант с использование стандартных библиотрек

# %%
# Инициализируем токенайзер для преобразования каждого текста в вектор. Максимальный размер словаря 5000 слов
tfidf_vectorizer = TfidfVectorizer(binary=True, max_features=5000)

# Преобразуем очищенные тексты в матрицы TFIDF
tfidf_embedings = tfidf_vectorizer.fit_transform(data['description'])

# Проверяем размерность полученного массива
tfidf_embedings.shape
# Out:
# (500, 3938)

# %%
# Вычисляем попарно косинусное расстояние между векторами в матрице
cos_matrix = cosine_similarity(tfidf_embedings)

# Находим индексы значений косинусного расстояния больше 0.8
pair_indexes = np.transpose(np.nonzero(cos_matrix > 0.8))

# Перебираем пары индексов
for x in pair_indexes:
    
    # Если индексы не равны друг другу, что означает, что сравнивались описания разных товаров
    if x[0] != x[1]:
        
        # Выводим пары описаний товаров
        print(df['description'][x])
# Out:
# 3      alpin guid pant skin climb ice switch rock tra...
# 158    alpin guid pant skin climb ice switch rock tra...
# Name: description, dtype: object
# 4      alpin wind jkt high ridg steep ice anyth alpin...
# 307    alpin wind jkt high ridg steep ice anyth alpin...
# Name: description, dtype: object
# 7      print band betina btm fullest coverag bottom b...
# 219    solid betina btm fullest coverag bottom betina...
# Name: description, dtype: object
# 26    compound cargo pant long ultim doeveryth pant ...
# 27    compound cargo pant reg ultim doeveryth pant b...
# Name: description, dtype: object
# 26     compound cargo pant long ultim doeveryth pant ...
# 451    compound cargo pant short ultim doeveryth pant...
# Name: description, dtype: object
# 27    compound cargo pant reg ultim doeveryth pant b...
# 26    compound cargo pant long ultim doeveryth pant ...
# Name: description, dtype: object
# 27     compound cargo pant reg ultim doeveryth pant b...
# 451    compound cargo pant short ultim doeveryth pant...
# Name: description, dtype: object
# 31     custodian pant long graveyard shift advantag q...
# 461    custodian pant reg graveyard shift advantag qu...
# Name: description, dtype: object
# 31     custodian pant long graveyard shift advantag q...
# 462    custodian pant short graveyard shift advantag ...
# Name: description, dtype: object
# 34     sweater vest imposs confus sweater vest found ...
# 281    sweater vest imposs confus sweater vest found ...
# Name: description, dtype: object
# 36     duck pant long essenti wear split log drive na...
# 480    duck pant reg essenti wear split log drive nai...
# Name: description, dtype: object
# 36     duck pant long essenti wear split log drive na...
# 481    duck pant short essenti wear split log drive n...
# Name: description, dtype: object
# 57    logo tshirt softwear ringspun organ cotton scr...
# 62    fli fish tshirt softwear ringspun organ cotton...
# Name: description, dtype: object
# 57    logo tshirt softwear ringspun organ cotton scr...
# 63    gpiw classic tshirt softwear ringspun organ co...
# Name: description, dtype: object
# 57    logo tshirt softwear ringspun organ cotton scr...
# 64    live simpli guitar tshirt softwear ringspun or...
# Name: description, dtype: object
# 57     logo tshirt softwear ringspun organ cotton scr...
# 431    girl live simpli deer tshirt softwear ringspun...
# Name: description, dtype: object
# 57     logo tshirt softwear ringspun organ cotton scr...
# 432    girl live simpli seal tshirt softwear ringspun...
# Name: description, dtype: object
# 62    fli fish tshirt softwear ringspun organ cotton...
# 57    logo tshirt softwear ringspun organ cotton scr...
# Name: description, dtype: object
# 62    fli fish tshirt softwear ringspun organ cotton...
# 63    gpiw classic tshirt softwear ringspun organ co...
# Name: description, dtype: object
# 62    fli fish tshirt softwear ringspun organ cotton...
# 64    live simpli guitar tshirt softwear ringspun or...
# Name: description, dtype: object
# 62     fli fish tshirt softwear ringspun organ cotton...
# 431    girl live simpli deer tshirt softwear ringspun...
# Name: description, dtype: object
# 62     fli fish tshirt softwear ringspun organ cotton...
# 432    girl live simpli seal tshirt softwear ringspun...
# Name: description, dtype: object
# 63    gpiw classic tshirt softwear ringspun organ co...
# 57    logo tshirt softwear ringspun organ cotton scr...
# Name: description, dtype: object
# 63    gpiw classic tshirt softwear ringspun organ co...
# 62    fli fish tshirt softwear ringspun organ cotton...
# Name: description, dtype: object
# 63    gpiw classic tshirt softwear ringspun organ co...
# 64    live simpli guitar tshirt softwear ringspun or...
# Name: description, dtype: object
# 64    live simpli guitar tshirt softwear ringspun or...
# 57    logo tshirt softwear ringspun organ cotton scr...
# Name: description, dtype: object
# 64    live simpli guitar tshirt softwear ringspun or...
# 62    fli fish tshirt softwear ringspun organ cotton...
# Name: description, dtype: object
# 64    live simpli guitar tshirt softwear ringspun or...
# 63    gpiw classic tshirt softwear ringspun organ co...
# Name: description, dtype: object
# 64     live simpli guitar tshirt softwear ringspun or...
# 431    girl live simpli deer tshirt softwear ringspun...
# Name: description, dtype: object
# 64     live simpli guitar tshirt softwear ringspun or...
# 432    girl live simpli seal tshirt softwear ringspun...
# Name: description, dtype: object
# 71     live simpli deer tshirt adapt simpli matter su...
# 333    live simpli deer tshirt adapt simpli matter su...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 334    live simpli guitar tshirt live life unplug lig...
# Name: description, dtype: object
# 75     ls island hopper shirt seren face seriou heat ...
# 124    ss island hopper shirt seren face seriou heat ...
# Name: description, dtype: object
# 76     ls rashguard upf fabric longsleev rashguard ke...
# 360    ss rashguard upf fabric shortsleev rashguard k...
# Name: description, dtype: object
# 81     lw r jkt high deck warbonnet peak immacul wind...
# 379    lw r jkt high deck warbonnet peak immacul wind...
# Name: description, dtype: object
# 84     jkt made thrive thin technic climb full alpin ...
# 196    jkt made thrive thin technic climb full alpin ...
# Name: description, dtype: object
# 106    rain shadow pant light enough afterthought dow...
# 350    rain shadow pant light enough afterthought dow...
# Name: description, dtype: object
# 107    reg fit organ ctn jeanslong organ cotton denim...
# 108    reg fit organ ctn jeansreg organ cotton denim ...
# Name: description, dtype: object
# 107    reg fit organ ctn jeanslong organ cotton denim...
# 389    reg fit organ ctn jeansshort organ cotton deni...
# Name: description, dtype: object
# 108    reg fit organ ctn jeansreg organ cotton denim ...
# 107    reg fit organ ctn jeanslong organ cotton denim...
# Name: description, dtype: object
# 108    reg fit organ ctn jeansreg organ cotton denim ...
# 389    reg fit organ ctn jeansshort organ cotton deni...
# Name: description, dtype: object
# 109    relax fit organ ctn jeansshor everyday goto ra...
# 390    relax fit organ ctn jeanslong everyday goto ra...
# Name: description, dtype: object
# 109    relax fit organ ctn jeansshor everyday goto ra...
# 391    relax fit organ ctn jeansreg everyday goto rar...
# Name: description, dtype: object
# 112    riverwalk felt high water slick bedrock cobbl ...
# 113    riverwalk stud high water slick bedrock cobbl ...
# Name: description, dtype: object
# 112    riverwalk felt high water slick bedrock cobbl ...
# 419    riverwalk sticki high water slick bedrock cobb...
# Name: description, dtype: object
# 113    riverwalk stud high water slick bedrock cobbl ...
# 112    riverwalk felt high water slick bedrock cobbl ...
# Name: description, dtype: object
# 113    riverwalk stud high water slick bedrock cobbl ...
# 419    riverwalk sticki high water slick bedrock cobb...
# Name: description, dtype: object
# 117    shop pant reg home truck insid shop pant made ...
# 118    shop pant short home truck insid shop pant mad...
# Name: description, dtype: object
# 117    shop pant reg home truck insid shop pant made ...
# 349    shop pant long home truck insid shop pant made...
# Name: description, dtype: object
# 118    shop pant short home truck insid shop pant mad...
# 117    shop pant reg home truck insid shop pant made ...
# Name: description, dtype: object
# 118    shop pant short home truck insid shop pant mad...
# 349    shop pant long home truck insid shop pant made...
# Name: description, dtype: object
# 119    simpl guid jkt skinin headlamp summit noon fin...
# 215    simpl guid jkt skinin headlamp summit noon fin...
# Name: description, dtype: object
# 124    ss island hopper shirt seren face seriou heat ...
# 75     ls island hopper shirt seren face seriou heat ...
# Name: description, dtype: object
# 140    torrentshel pant theyr lightweight waterproof ...
# 274    torrentshel pant theyr lightweight waterproof ...
# Name: description, dtype: object
# 152    watermast wader long blackberri barbwir basalt...
# 153    watermast wader short blackberri barbwir basal...
# Name: description, dtype: object
# 152    watermast wader long blackberri barbwir basalt...
# 354    watermast wader king blackberri barbwir basalt...
# Name: description, dtype: object
# 152    watermast wader long blackberri barbwir basalt...
# 366    watermast wader reg blackberri barbwir basaltt...
# Name: description, dtype: object
# 153    watermast wader short blackberri barbwir basal...
# 152    watermast wader long blackberri barbwir basalt...
# Name: description, dtype: object
# 153    watermast wader short blackberri barbwir basal...
# 354    watermast wader king blackberri barbwir basalt...
# Name: description, dtype: object
# 153    watermast wader short blackberri barbwir basal...
# 366    watermast wader reg blackberri barbwir basaltt...
# Name: description, dtype: object
# 158    alpin guid pant skin climb ice switch rock tra...
# 3      alpin guid pant skin climb ice switch rock tra...
# Name: description, dtype: object
# 178    sweater there much see feet chasm view bivi ve...
# 472    sweater there much see feet chasm view bivi ve...
# Name: description, dtype: object
# 183    guid jkt sharp granit sticki vergla untrack li...
# 437    guid jkt sharp granit sticki vergla untrack li...
# Name: description, dtype: object
# 187    intercontinent pant long youll like flatter dr...
# 304    intercontinent pant reg youll like flatter dra...
# Name: description, dtype: object
# 196    jkt made thrive thin technic climb full alpin ...
# 84     jkt made thrive thin technic climb full alpin ...
# Name: description, dtype: object
# 199    merino graphic tshirt feel good laugh lightest...
# 200    merino tank finespun cool enough lower tempera...
# Name: description, dtype: object
# 199    merino graphic tshirt feel good laugh lightest...
# 259    merino crew lightest merino layer silkysoft ye...
# Name: description, dtype: object
# 199    merino graphic tshirt feel good laugh lightest...
# 264    merino tshirt soft worth linger lightest merin...
# Name: description, dtype: object
# 200    merino tank finespun cool enough lower tempera...
# 199    merino graphic tshirt feel good laugh lightest...
# Name: description, dtype: object
# 200    merino tank finespun cool enough lower tempera...
# 259    merino crew lightest merino layer silkysoft ye...
# Name: description, dtype: object
# 200    merino tank finespun cool enough lower tempera...
# 264    merino tshirt soft worth linger lightest merin...
# Name: description, dtype: object
# 203    micro puff vest mani alpin shiverfest leav mum...
# 415    micro puff vest mani alpin shiverfest leav mum...
# Name: description, dtype: object
# 209    nine trail vest simplic action vest protect co...
# 363    nine trail vest simplic action vest protect co...
# Name: description, dtype: object
# 210    r jkt modern mountain stapl adapt r jacket ser...
# 380    r jkt modern mountain stapl adapt r jacket ser...
# Name: description, dtype: object
# 211    rain shadow jkt stay insid isnt way stay dri e...
# 381    rain shadow jkt stay insid isnt way stay dri e...
# Name: description, dtype: object
# 214    seren tight long soft stretchi unrestrict mobi...
# 246    seren tight soft stretchi unrestrict mobil mat...
# Name: description, dtype: object
# 215    simpl guid jkt skinin headlamp summit noon fin...
# 119    simpl guid jkt skinin headlamp summit noon fin...
# Name: description, dtype: object
# 218    solid adour btm adour featur scoop lowris fron...
# 290    print adour btm adour slightli scoop lowris fr...
# Name: description, dtype: object
# 219    solid betina btm fullest coverag bottom betina...
# 7      print band betina btm fullest coverag bottom b...
# Name: description, dtype: object
# 221    solid bibiana top athlet bibiana top racerback...
# 241    print bibiana top athlet bibiana top racerback...
# Name: description, dtype: object
# 241    print bibiana top athlet bibiana top racerback...
# 221    solid bibiana top athlet bibiana top racerback...
# Name: description, dtype: object
# 242    print boucau halter top boucau soft tie neck b...
# 251    solid boucau halter top boucau soft tie neck b...
# Name: description, dtype: object
# 243    print kupala top fix triangl bikini top kupala...
# 252    solid kupala top fix triangl bikini top kupala...
# Name: description, dtype: object
# 246    seren tight soft stretchi unrestrict mobil mat...
# 214    seren tight long soft stretchi unrestrict mobi...
# Name: description, dtype: object
# 251    solid boucau halter top boucau soft tie neck b...
# 242    print boucau halter top boucau soft tie neck b...
# Name: description, dtype: object
# 252    solid kupala top fix triangl bikini top kupala...
# 243    print kupala top fix triangl bikini top kupala...
# Name: description, dtype: object
# 254    solid suname btm stayput suname fit straight a...
# 261    print suname btm stayput suname fit straight a...
# Name: description, dtype: object
# 259    merino crew lightest merino layer silkysoft ye...
# 199    merino graphic tshirt feel good laugh lightest...
# Name: description, dtype: object
# 259    merino crew lightest merino layer silkysoft ye...
# 200    merino tank finespun cool enough lower tempera...
# Name: description, dtype: object
# 259    merino crew lightest merino layer silkysoft ye...
# 264    merino tshirt soft worth linger lightest merin...
# Name: description, dtype: object
# 261    print suname btm stayput suname fit straight a...
# 254    solid suname btm stayput suname fit straight a...
# Name: description, dtype: object
# 262    r fullzip jkt stretch breath wick warm wonder ...
# 377    r fullzip jkt stretch breath wick warm wonder ...
# Name: description, dtype: object
# 264    merino tshirt soft worth linger lightest merin...
# 199    merino graphic tshirt feel good laugh lightest...
# Name: description, dtype: object
# 264    merino tshirt soft worth linger lightest merin...
# 200    merino tank finespun cool enough lower tempera...
# Name: description, dtype: object
# 264    merino tshirt soft worth linger lightest merin...
# 259    merino crew lightest merino layer silkysoft ye...
# Name: description, dtype: object
# 266    storm light jkt emerg classic inspir origin st...
# 385    storm light jkt emerg classic inspir origin st...
# Name: description, dtype: object
# 267    stretch ascent jkt simpl stretchi lightweight ...
# 386    stretch ascent jkt simpl stretchi lightweight ...
# Name: description, dtype: object
# 273    torrentshel jkt tropic rain forest share least...
# 326    torrentshel jkt tropic rain forest share least...
# Name: description, dtype: object
# 274    torrentshel pant theyr lightweight waterproof ...
# 140    torrentshel pant theyr lightweight waterproof ...
# Name: description, dtype: object
# 279    nano puff po versatil piec insul make nano puf...
# 457    nano puff po alreadi cult classic ambassador t...
# Name: description, dtype: object
# 281    sweater vest imposs confus sweater vest found ...
# 34     sweater vest imposs confus sweater vest found ...
# Name: description, dtype: object
# 285    freedom roam tshirt global warm habitat destru...
# 491    freedom roam tshirt global warm habitat destru...
# Name: description, dtype: object
# 290    print adour btm adour slightli scoop lowris fr...
# 218    solid adour btm adour featur scoop lowris fron...
# Name: description, dtype: object
# 292    houdini fullzip jkt see dont like sun blusteri...
# 404    houdini fullzip jkt see dont like sun blusteri...
# Name: description, dtype: object
# 304    intercontinent pant reg youll like flatter dra...
# 187    intercontinent pant long youll like flatter dr...
# Name: description, dtype: object
# 307    alpin wind jkt high ridg steep ice anyth alpin...
# 4      alpin wind jkt high ridg steep ice anyth alpin...
# Name: description, dtype: object
# 326    torrentshel jkt tropic rain forest share least...
# 273    torrentshel jkt tropic rain forest share least...
# Name: description, dtype: object
# 333    live simpli deer tshirt adapt simpli matter su...
# 71     live simpli deer tshirt adapt simpli matter su...
# Name: description, dtype: object
# 334    live simpli guitar tshirt live life unplug lig...
# 72     live simpli guitar tshirt live life unplug tee...
# Name: description, dtype: object
# 349    shop pant long home truck insid shop pant made...
# 117    shop pant reg home truck insid shop pant made ...
# Name: description, dtype: object
# 349    shop pant long home truck insid shop pant made...
# 118    shop pant short home truck insid shop pant mad...
# Name: description, dtype: object
# 350    rain shadow pant light enough afterthought dow...
# 106    rain shadow pant light enough afterthought dow...
# Name: description, dtype: object
# 354    watermast wader king blackberri barbwir basalt...
# 152    watermast wader long blackberri barbwir basalt...
# Name: description, dtype: object
# 354    watermast wader king blackberri barbwir basalt...
# 153    watermast wader short blackberri barbwir basal...
# Name: description, dtype: object
# 354    watermast wader king blackberri barbwir basalt...
# 366    watermast wader reg blackberri barbwir basaltt...
# Name: description, dtype: object
# 360    ss rashguard upf fabric shortsleev rashguard k...
# 76     ls rashguard upf fabric longsleev rashguard ke...
# Name: description, dtype: object
# 363    nine trail vest simplic action vest protect co...
# 209    nine trail vest simplic action vest protect co...
# Name: description, dtype: object
# 366    watermast wader reg blackberri barbwir basaltt...
# 152    watermast wader long blackberri barbwir basalt...
# Name: description, dtype: object
# 366    watermast wader reg blackberri barbwir basaltt...
# 153    watermast wader short blackberri barbwir basal...
# Name: description, dtype: object
# 366    watermast wader reg blackberri barbwir basaltt...
# 354    watermast wader king blackberri barbwir basalt...
# Name: description, dtype: object
# 368    stand short theyv around plu year reenvis rein...
# 369    stand short theyv around plu year reenvis rein...
# Name: description, dtype: object
# 369    stand short theyv around plu year reenvis rein...
# 368    stand short theyv around plu year reenvis rein...
# Name: description, dtype: object
# 377    r fullzip jkt stretch breath wick warm wonder ...
# 262    r fullzip jkt stretch breath wick warm wonder ...
# Name: description, dtype: object
# 378    lw guid pant backcountri version immens popula...
# 383    lw guid pant backcountri version immens popula...
# Name: description, dtype: object
# 379    lw r jkt high deck warbonnet peak immacul wind...
# 81     lw r jkt high deck warbonnet peak immacul wind...
# Name: description, dtype: object
# 380    r jkt modern mountain stapl adapt r jacket ser...
# 210    r jkt modern mountain stapl adapt r jacket ser...
# Name: description, dtype: object
# 381    rain shadow jkt stay insid isnt way stay dri e...
# 211    rain shadow jkt stay insid isnt way stay dri e...
# Name: description, dtype: object
# 383    lw guid pant backcountri version immens popula...
# 378    lw guid pant backcountri version immens popula...
# Name: description, dtype: object
# 385    storm light jkt emerg classic inspir origin st...
# 266    storm light jkt emerg classic inspir origin st...
# Name: description, dtype: object
# 386    stretch ascent jkt simpl stretchi lightweight ...
# 267    stretch ascent jkt simpl stretchi lightweight ...
# Name: description, dtype: object
# 389    reg fit organ ctn jeansshort organ cotton deni...
# 107    reg fit organ ctn jeanslong organ cotton denim...
# Name: description, dtype: object
# 389    reg fit organ ctn jeansshort organ cotton deni...
# 108    reg fit organ ctn jeansreg organ cotton denim ...
# Name: description, dtype: object
# 390    relax fit organ ctn jeanslong everyday goto ra...
# 109    relax fit organ ctn jeansshor everyday goto ra...
# Name: description, dtype: object
# 390    relax fit organ ctn jeanslong everyday goto ra...
# 391    relax fit organ ctn jeansreg everyday goto rar...
# Name: description, dtype: object
# 391    relax fit organ ctn jeansreg everyday goto rar...
# 109    relax fit organ ctn jeansshor everyday goto ra...
# Name: description, dtype: object
# 391    relax fit organ ctn jeansreg everyday goto rar...
# 390    relax fit organ ctn jeanslong everyday goto ra...
# Name: description, dtype: object
# 404    houdini fullzip jkt see dont like sun blusteri...
# 292    houdini fullzip jkt see dont like sun blusteri...
# Name: description, dtype: object
# 415    micro puff vest mani alpin shiverfest leav mum...
# 203    micro puff vest mani alpin shiverfest leav mum...
# Name: description, dtype: object
# 419    riverwalk sticki high water slick bedrock cobb...
# 112    riverwalk felt high water slick bedrock cobbl ...
# Name: description, dtype: object
# 419    riverwalk sticki high water slick bedrock cobb...
# 113    riverwalk stud high water slick bedrock cobbl ...
# Name: description, dtype: object
# 431    girl live simpli deer tshirt softwear ringspun...
# 57     logo tshirt softwear ringspun organ cotton scr...
# Name: description, dtype: object
# 431    girl live simpli deer tshirt softwear ringspun...
# 62     fli fish tshirt softwear ringspun organ cotton...
# Name: description, dtype: object
# 431    girl live simpli deer tshirt softwear ringspun...
# 64     live simpli guitar tshirt softwear ringspun or...
# Name: description, dtype: object
# 431    girl live simpli deer tshirt softwear ringspun...
# 432    girl live simpli seal tshirt softwear ringspun...
# Name: description, dtype: object
# 432    girl live simpli seal tshirt softwear ringspun...
# 57     logo tshirt softwear ringspun organ cotton scr...
# Name: description, dtype: object
# 432    girl live simpli seal tshirt softwear ringspun...
# 62     fli fish tshirt softwear ringspun organ cotton...
# Name: description, dtype: object
# 432    girl live simpli seal tshirt softwear ringspun...
# 64     live simpli guitar tshirt softwear ringspun or...
# Name: description, dtype: object
# 432    girl live simpli seal tshirt softwear ringspun...
# 431    girl live simpli deer tshirt softwear ringspun...
# Name: description, dtype: object
# 437    guid jkt sharp granit sticki vergla untrack li...
# 183    guid jkt sharp granit sticki vergla untrack li...
# Name: description, dtype: object
# 451    compound cargo pant short ultim doeveryth pant...
# 26     compound cargo pant long ultim doeveryth pant ...
# Name: description, dtype: object
# 451    compound cargo pant short ultim doeveryth pant...
# 27     compound cargo pant reg ultim doeveryth pant b...
# Name: description, dtype: object
# 454    guidewat wader king built guidewat wader tough...
# 467    guidewat wader reg built guidewat wader toughe...
# Name: description, dtype: object
# 455    critic mass built twowheel commut critic mass ...
# 485    half mass size ride bike fine tune hold day wo...
# Name: description, dtype: object
# 457    nano puff po alreadi cult classic ambassador t...
# 279    nano puff po versatil piec insul make nano puf...
# Name: description, dtype: object
# 461    custodian pant reg graveyard shift advantag qu...
# 31     custodian pant long graveyard shift advantag q...
# Name: description, dtype: object
# 461    custodian pant reg graveyard shift advantag qu...
# 462    custodian pant short graveyard shift advantag ...
# Name: description, dtype: object
# 462    custodian pant short graveyard shift advantag ...
# 31     custodian pant long graveyard shift advantag q...
# Name: description, dtype: object
# 462    custodian pant short graveyard shift advantag ...
# 461    custodian pant reg graveyard shift advantag qu...
# Name: description, dtype: object
# 467    guidewat wader reg built guidewat wader toughe...
# 454    guidewat wader king built guidewat wader tough...
# Name: description, dtype: object
# 469    babi live simpli deer tshirt live simpli deer ...
# 470    babi live simpli seal tshirt swim fish haul si...
# Name: description, dtype: object
# 470    babi live simpli seal tshirt swim fish haul si...
# 469    babi live simpli deer tshirt live simpli deer ...
# Name: description, dtype: object
# 472    sweater there much see feet chasm view bivi ve...
# 178    sweater there much see feet chasm view bivi ve...
# Name: description, dtype: object
# 480    duck pant reg essenti wear split log drive nai...
# 36     duck pant long essenti wear split log drive na...
# Name: description, dtype: object
# 480    duck pant reg essenti wear split log drive nai...
# 481    duck pant short essenti wear split log drive n...
# Name: description, dtype: object
# 481    duck pant short essenti wear split log drive n...
# 36     duck pant long essenti wear split log drive na...
# Name: description, dtype: object
# 481    duck pant short essenti wear split log drive n...
# 480    duck pant reg essenti wear split log drive nai...
# Name: description, dtype: object
# 485    half mass size ride bike fine tune hold day wo...
# 455    critic mass built twowheel commut critic mass ...
# Name: description, dtype: object
# 491    freedom roam tshirt global warm habitat destru...
# 285    freedom roam tshirt global warm habitat destru...
# Name: description, dtype: object

# %% [markdown]
# # 2-й вариант. Написал свой tf-idf

# %%
# Добавим новое поле description_split, которое будет списком слов
data["description_split"] = data["description"].apply(lambda x: x.split())

# %%
# Создаем словарь
vocabulary = []
for i, row  in data.iterrows():
    for j in data["description_split"][i]:
        if j not in vocabulary:
            vocabulary.append(j)
word2idx = {w: idx for (idx, w) in enumerate(vocabulary)}
idx2word = {idx: w for (idx, w) in enumerate(vocabulary)}

vocabulary_size = len(vocabulary)

# %%
# Кол-во документов
len_doc= len(data)

# %%
# Размер словаря
vocabulary_size
# Out:
# 3947

# %%
class tf_idf_model():
    def __init__(self, data, len_doc = len_doc, vocabulary_size = vocabulary_size):
        self.data = data 
        self.tf_matrix = np.zeros((len_doc, vocabulary_size)) 
        self.idf = {}
        self.tf_idf_matrix = np.zeros((len_doc, vocabulary_size)) 
        
    def tf_bild(self, data):
        for i, row  in self.data.iterrows():         
            for w1 in data["description_split"][i]:                                                           
                if w1 in vocabulary:
                    self.tf_matrix[ i, word2idx[w1] ] +=  (1 / len(data["description_split"][i]))
        return self.tf_matrix
    def idf_bild(self, data):
        for word in vocabulary:
            k = 0    
            for i, row  in data.iterrows():  
                if word in data["description_split"][i]:
                    k += 1
            self.idf[word] =  np.log10(len_doc / k)
        return self.idf

    def forward(self, data):
        tf_matrix = self.tf_bild(data)
        idf = self.idf_bild(data)
        
        for word in vocabulary:
            for i in range(len_doc):
                self.tf_idf_matrix[i][word2idx[word]] = tf_matrix[i][word2idx[word]] * idf[word]
        return self.tf_idf_matrix

# %%
my_tf_idf = tf_idf_model(data)

# %%
tf_idf_matrix = pd.DataFrame(my_tf_idf.forward(data))

# %%
tf_idf_matrix
# Out:
#          0         1         2         3         4         5         6     \
# 0    0.012735  0.025728  0.088314  0.018618  0.031023  0.027563  0.018219
# 1    0.022610  0.000000  0.058801  0.000000  0.000000  0.000000  0.000000
# 2    0.013678  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 495  0.008724  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 496  0.008588  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 497  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 498  0.011541  0.011658  0.000000  0.000000  0.000000  0.000000  0.000000
# 499  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          7         8         9     ...     3937     3938     3939      3940  \
# 0    0.006249  0.010420  0.031023  ...  0.00000  0.00000  0.00000  0.000000
# 1    0.000000  0.000000  0.000000  ...  0.00000  0.00000  0.00000  0.000000
# 2    0.000000  0.011192  0.000000  ...  0.00000  0.00000  0.00000  0.000000
# 3    0.008300  0.000000  0.000000  ...  0.00000  0.00000  0.00000  0.000000
# 4    0.000000  0.000000  0.000000  ...  0.00000  0.00000  0.00000  0.000000
# ..        ...       ...       ...  ...      ...      ...      ...       ...
# 495  0.000000  0.000000  0.000000  ...  0.00000  0.00000  0.00000  0.000000
# 496  0.004214  0.007028  0.000000  ...  0.00000  0.00000  0.00000  0.000000
# 497  0.008629  0.000000  0.000000  ...  0.02142  0.02142  0.02142  0.000000
# 498  0.000000  0.000000  0.000000  ...  0.00000  0.00000  0.00000  0.028114
# 499  0.000000  0.000000  0.000000  ...  0.00000  0.00000  0.00000  0.000000
#
#          3941      3942      3943      3944      3945      3946
# 0    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ..        ...       ...       ...       ...       ...       ...
# 495  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 496  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 497  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 498  0.028114  0.028114  0.028114  0.028114  0.028114  0.000000
# 499  0.000000  0.000000  0.000000  0.000000  0.000000  0.032518
#
# [500 rows x 3947 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity               # Метрика измерения косинусного расстояния между векторами
cosine_similarity_tf_idf_matrix = cosine_similarity(tf_idf_matrix)

# %%
# Находим индексы значений косинусного расстояния больше 0.8
pair_indexes = np.transpose(np.nonzero(cosine_similarity_tf_idf_matrix > 0.8))

# Перебираем пары индексов
for x in pair_indexes:
    
    # Если индексы не равны друг другу, что означает, что сравнивались описания разных товаров
    if x[0] != x[1]:
        
        # Выводим пары описаний товаров
        print(df['description'][x])
# Out:
# 3      alpin guid pant skin climb ice switch rock tra...
# 158    alpin guid pant skin climb ice switch rock tra...
# Name: description, dtype: object
# 4      alpin wind jkt high ridg steep ice anyth alpin...
# 307    alpin wind jkt high ridg steep ice anyth alpin...
# Name: description, dtype: object
# 7      print band betina btm fullest coverag bottom b...
# 219    solid betina btm fullest coverag bottom betina...
# Name: description, dtype: object
# 26    compound cargo pant long ultim doeveryth pant ...
# 27    compound cargo pant reg ultim doeveryth pant b...
# Name: description, dtype: object
# 26     compound cargo pant long ultim doeveryth pant ...
# 451    compound cargo pant short ultim doeveryth pant...
# Name: description, dtype: object
# 27    compound cargo pant reg ultim doeveryth pant b...
# 26    compound cargo pant long ultim doeveryth pant ...
# Name: description, dtype: object
# 27     compound cargo pant reg ultim doeveryth pant b...
# 451    compound cargo pant short ultim doeveryth pant...
# Name: description, dtype: object
# 31     custodian pant long graveyard shift advantag q...
# 461    custodian pant reg graveyard shift advantag qu...
# Name: description, dtype: object
# 31     custodian pant long graveyard shift advantag q...
# 462    custodian pant short graveyard shift advantag ...
# Name: description, dtype: object
# 34     sweater vest imposs confus sweater vest found ...
# 281    sweater vest imposs confus sweater vest found ...
# Name: description, dtype: object
# 36     duck pant long essenti wear split log drive na...
# 480    duck pant reg essenti wear split log drive nai...
# Name: description, dtype: object
# 36     duck pant long essenti wear split log drive na...
# 481    duck pant short essenti wear split log drive n...
# Name: description, dtype: object
# 48     great divid stand wave bluewat wind chop there...
# 133    sub divid tough water resist great divid sub c...
# Name: description, dtype: object
# 57    logo tshirt softwear ringspun organ cotton scr...
# 62    fli fish tshirt softwear ringspun organ cotton...
# Name: description, dtype: object
# 57    logo tshirt softwear ringspun organ cotton scr...
# 63    gpiw classic tshirt softwear ringspun organ co...
# Name: description, dtype: object
# 57    logo tshirt softwear ringspun organ cotton scr...
# 64    live simpli guitar tshirt softwear ringspun or...
# Name: description, dtype: object
# 57     logo tshirt softwear ringspun organ cotton scr...
# 431    girl live simpli deer tshirt softwear ringspun...
# Name: description, dtype: object
# 57     logo tshirt softwear ringspun organ cotton scr...
# 432    girl live simpli seal tshirt softwear ringspun...
# Name: description, dtype: object
# 62    fli fish tshirt softwear ringspun organ cotton...
# 57    logo tshirt softwear ringspun organ cotton scr...
# Name: description, dtype: object
# 62    fli fish tshirt softwear ringspun organ cotton...
# 63    gpiw classic tshirt softwear ringspun organ co...
# Name: description, dtype: object
# 62    fli fish tshirt softwear ringspun organ cotton...
# 64    live simpli guitar tshirt softwear ringspun or...
# Name: description, dtype: object
# 62     fli fish tshirt softwear ringspun organ cotton...
# 431    girl live simpli deer tshirt softwear ringspun...
# Name: description, dtype: object
# 62     fli fish tshirt softwear ringspun organ cotton...
# 432    girl live simpli seal tshirt softwear ringspun...
# Name: description, dtype: object
# 63    gpiw classic tshirt softwear ringspun organ co...
# 57    logo tshirt softwear ringspun organ cotton scr...
# Name: description, dtype: object
# 63    gpiw classic tshirt softwear ringspun organ co...
# 62    fli fish tshirt softwear ringspun organ cotton...
# Name: description, dtype: object
# 64    live simpli guitar tshirt softwear ringspun or...
# 57    logo tshirt softwear ringspun organ cotton scr...
# Name: description, dtype: object
# 64    live simpli guitar tshirt softwear ringspun or...
# 62    fli fish tshirt softwear ringspun organ cotton...
# Name: description, dtype: object
# 64     live simpli guitar tshirt softwear ringspun or...
# 431    girl live simpli deer tshirt softwear ringspun...
# Name: description, dtype: object
# 64     live simpli guitar tshirt softwear ringspun or...
# 432    girl live simpli seal tshirt softwear ringspun...
# Name: description, dtype: object
# 71     live simpli deer tshirt adapt simpli matter su...
# 333    live simpli deer tshirt adapt simpli matter su...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 334    live simpli guitar tshirt live life unplug lig...
# Name: description, dtype: object
# 75     ls island hopper shirt seren face seriou heat ...
# 124    ss island hopper shirt seren face seriou heat ...
# Name: description, dtype: object
# 76     ls rashguard upf fabric longsleev rashguard ke...
# 360    ss rashguard upf fabric shortsleev rashguard k...
# Name: description, dtype: object
# 81     lw r jkt high deck warbonnet peak immacul wind...
# 379    lw r jkt high deck warbonnet peak immacul wind...
# Name: description, dtype: object
# 84     jkt made thrive thin technic climb full alpin ...
# 196    jkt made thrive thin technic climb full alpin ...
# Name: description, dtype: object
# 89     merino tshirt stay calm collect amid frenzi na...
# 406    merino crew soft longsleev tee work sweat bike...
# Name: description, dtype: object
# 95     nine trail jkt somewher bridger ridg run norma...
# 280    nine trail jkt nine trail jacket women whose i...
# Name: description, dtype: object
# 96     nine trail short view trail sanctuari run mean...
# 208    nine trail short mountain bike trail run fast ...
# Name: description, dtype: object
# 106    rain shadow pant light enough afterthought dow...
# 350    rain shadow pant light enough afterthought dow...
# Name: description, dtype: object
# 107    reg fit organ ctn jeanslong organ cotton denim...
# 108    reg fit organ ctn jeansreg organ cotton denim ...
# Name: description, dtype: object
# 107    reg fit organ ctn jeanslong organ cotton denim...
# 389    reg fit organ ctn jeansshort organ cotton deni...
# Name: description, dtype: object
# 108    reg fit organ ctn jeansreg organ cotton denim ...
# 107    reg fit organ ctn jeanslong organ cotton denim...
# Name: description, dtype: object
# 108    reg fit organ ctn jeansreg organ cotton denim ...
# 389    reg fit organ ctn jeansshort organ cotton deni...
# Name: description, dtype: object
# 109    relax fit organ ctn jeansshor everyday goto ra...
# 390    relax fit organ ctn jeanslong everyday goto ra...
# Name: description, dtype: object
# 109    relax fit organ ctn jeansshor everyday goto ra...
# 391    relax fit organ ctn jeansreg everyday goto rar...
# Name: description, dtype: object
# 112    riverwalk felt high water slick bedrock cobbl ...
# 113    riverwalk stud high water slick bedrock cobbl ...
# Name: description, dtype: object
# 112    riverwalk felt high water slick bedrock cobbl ...
# 419    riverwalk sticki high water slick bedrock cobb...
# Name: description, dtype: object
# 113    riverwalk stud high water slick bedrock cobbl ...
# 112    riverwalk felt high water slick bedrock cobbl ...
# Name: description, dtype: object
# 113    riverwalk stud high water slick bedrock cobbl ...
# 419    riverwalk sticki high water slick bedrock cobb...
# Name: description, dtype: object
# 117    shop pant reg home truck insid shop pant made ...
# 118    shop pant short home truck insid shop pant mad...
# Name: description, dtype: object
# 117    shop pant reg home truck insid shop pant made ...
# 349    shop pant long home truck insid shop pant made...
# Name: description, dtype: object
# 118    shop pant short home truck insid shop pant mad...
# 117    shop pant reg home truck insid shop pant made ...
# Name: description, dtype: object
# 118    shop pant short home truck insid shop pant mad...
# 349    shop pant long home truck insid shop pant made...
# Name: description, dtype: object
# 119    simpl guid jkt skinin headlamp summit noon fin...
# 215    simpl guid jkt skinin headlamp summit noon fin...
# Name: description, dtype: object
# 124    ss island hopper shirt seren face seriou heat ...
# 75     ls island hopper shirt seren face seriou heat ...
# Name: description, dtype: object
# 133    sub divid tough water resist great divid sub c...
# 48     great divid stand wave bluewat wind chop there...
# Name: description, dtype: object
# 140    torrentshel pant theyr lightweight waterproof ...
# 274    torrentshel pant theyr lightweight waterproof ...
# Name: description, dtype: object
# 152    watermast wader long blackberri barbwir basalt...
# 153    watermast wader short blackberri barbwir basal...
# Name: description, dtype: object
# 152    watermast wader long blackberri barbwir basalt...
# 354    watermast wader king blackberri barbwir basalt...
# Name: description, dtype: object
# 152    watermast wader long blackberri barbwir basalt...
# 366    watermast wader reg blackberri barbwir basaltt...
# Name: description, dtype: object
# 153    watermast wader short blackberri barbwir basal...
# 152    watermast wader long blackberri barbwir basalt...
# Name: description, dtype: object
# 153    watermast wader short blackberri barbwir basal...
# 354    watermast wader king blackberri barbwir basalt...
# Name: description, dtype: object
# 153    watermast wader short blackberri barbwir basal...
# 366    watermast wader reg blackberri barbwir basaltt...
# Name: description, dtype: object
# 158    alpin guid pant skin climb ice switch rock tra...
# 3      alpin guid pant skin climb ice switch rock tra...
# Name: description, dtype: object
# 178    sweater there much see feet chasm view bivi ve...
# 472    sweater there much see feet chasm view bivi ve...
# Name: description, dtype: object
# 183    guid jkt sharp granit sticki vergla untrack li...
# 437    guid jkt sharp granit sticki vergla untrack li...
# Name: description, dtype: object
# 187    intercontinent pant long youll like flatter dr...
# 304    intercontinent pant reg youll like flatter dra...
# Name: description, dtype: object
# 196    jkt made thrive thin technic climb full alpin ...
# 84     jkt made thrive thin technic climb full alpin ...
# Name: description, dtype: object
# 199    merino graphic tshirt feel good laugh lightest...
# 200    merino tank finespun cool enough lower tempera...
# Name: description, dtype: object
# 199    merino graphic tshirt feel good laugh lightest...
# 259    merino crew lightest merino layer silkysoft ye...
# Name: description, dtype: object
# 199    merino graphic tshirt feel good laugh lightest...
# 264    merino tshirt soft worth linger lightest merin...
# Name: description, dtype: object
# 200    merino tank finespun cool enough lower tempera...
# 199    merino graphic tshirt feel good laugh lightest...
# Name: description, dtype: object
# 200    merino tank finespun cool enough lower tempera...
# 259    merino crew lightest merino layer silkysoft ye...
# Name: description, dtype: object
# 200    merino tank finespun cool enough lower tempera...
# 264    merino tshirt soft worth linger lightest merin...
# Name: description, dtype: object
# 203    micro puff vest mani alpin shiverfest leav mum...
# 415    micro puff vest mani alpin shiverfest leav mum...
# Name: description, dtype: object
# 208    nine trail short mountain bike trail run fast ...
# 96     nine trail short view trail sanctuari run mean...
# Name: description, dtype: object
# 209    nine trail vest simplic action vest protect co...
# 363    nine trail vest simplic action vest protect co...
# Name: description, dtype: object
# 210    r jkt modern mountain stapl adapt r jacket ser...
# 380    r jkt modern mountain stapl adapt r jacket ser...
# Name: description, dtype: object
# 211    rain shadow jkt stay insid isnt way stay dri e...
# 381    rain shadow jkt stay insid isnt way stay dri e...
# Name: description, dtype: object
# 214    seren tight long soft stretchi unrestrict mobi...
# 246    seren tight soft stretchi unrestrict mobil mat...
# Name: description, dtype: object
# 215    simpl guid jkt skinin headlamp summit noon fin...
# 119    simpl guid jkt skinin headlamp summit noon fin...
# Name: description, dtype: object
# 218    solid adour btm adour featur scoop lowris fron...
# 290    print adour btm adour slightli scoop lowris fr...
# Name: description, dtype: object
# 219    solid betina btm fullest coverag bottom betina...
# 7      print band betina btm fullest coverag bottom b...
# Name: description, dtype: object
# 221    solid bibiana top athlet bibiana top racerback...
# 241    print bibiana top athlet bibiana top racerback...
# Name: description, dtype: object
# 241    print bibiana top athlet bibiana top racerback...
# 221    solid bibiana top athlet bibiana top racerback...
# Name: description, dtype: object
# 242    print boucau halter top boucau soft tie neck b...
# 251    solid boucau halter top boucau soft tie neck b...
# Name: description, dtype: object
# 243    print kupala top fix triangl bikini top kupala...
# 252    solid kupala top fix triangl bikini top kupala...
# Name: description, dtype: object
# 244    runshad tshirt backcountri anyplac move comfor...
# 347    runshad tshirt there long trail ahead your gel...
# Name: description, dtype: object
# 246    seren tight soft stretchi unrestrict mobil mat...
# 214    seren tight long soft stretchi unrestrict mobi...
# Name: description, dtype: object
# 251    solid boucau halter top boucau soft tie neck b...
# 242    print boucau halter top boucau soft tie neck b...
# Name: description, dtype: object
# 252    solid kupala top fix triangl bikini top kupala...
# 243    print kupala top fix triangl bikini top kupala...
# Name: description, dtype: object
# 253    solid pari btm boyshortstyl pari bottom fit lo...
# 260    print pari btm style like boy short pari botto...
# Name: description, dtype: object
# 254    solid suname btm stayput suname fit straight a...
# 261    print suname btm stayput suname fit straight a...
# Name: description, dtype: object
# 259    merino crew lightest merino layer silkysoft ye...
# 199    merino graphic tshirt feel good laugh lightest...
# Name: description, dtype: object
# 259    merino crew lightest merino layer silkysoft ye...
# 200    merino tank finespun cool enough lower tempera...
# Name: description, dtype: object
# 259    merino crew lightest merino layer silkysoft ye...
# 264    merino tshirt soft worth linger lightest merin...
# Name: description, dtype: object
# 260    print pari btm style like boy short pari botto...
# 253    solid pari btm boyshortstyl pari bottom fit lo...
# Name: description, dtype: object
# 261    print suname btm stayput suname fit straight a...
# 254    solid suname btm stayput suname fit straight a...
# Name: description, dtype: object
# 262    r fullzip jkt stretch breath wick warm wonder ...
# 377    r fullzip jkt stretch breath wick warm wonder ...
# Name: description, dtype: object
# 264    merino tshirt soft worth linger lightest merin...
# 199    merino graphic tshirt feel good laugh lightest...
# Name: description, dtype: object
# 264    merino tshirt soft worth linger lightest merin...
# 200    merino tank finespun cool enough lower tempera...
# Name: description, dtype: object
# 264    merino tshirt soft worth linger lightest merin...
# 259    merino crew lightest merino layer silkysoft ye...
# Name: description, dtype: object
# 265    merino bottom thank dri warm forward progress ...
# 405    merino bottom stopandgo pace like alpin climb ...
# Name: description, dtype: object
# 266    storm light jkt emerg classic inspir origin st...
# 385    storm light jkt emerg classic inspir origin st...
# Name: description, dtype: object
# 267    stretch ascent jkt simpl stretchi lightweight ...
# 386    stretch ascent jkt simpl stretchi lightweight ...
# Name: description, dtype: object
# 273    torrentshel jkt tropic rain forest share least...
# 326    torrentshel jkt tropic rain forest share least...
# Name: description, dtype: object
# 274    torrentshel pant theyr lightweight waterproof ...
# 140    torrentshel pant theyr lightweight waterproof ...
# Name: description, dtype: object
# 279    nano puff po versatil piec insul make nano puf...
# 457    nano puff po alreadi cult classic ambassador t...
# Name: description, dtype: object
# 280    nine trail jkt nine trail jacket women whose i...
# 95     nine trail jkt somewher bridger ridg run norma...
# Name: description, dtype: object
# 281    sweater vest imposs confus sweater vest found ...
# 34     sweater vest imposs confus sweater vest found ...
# Name: description, dtype: object
# 285    freedom roam tshirt global warm habitat destru...
# 491    freedom roam tshirt global warm habitat destru...
# Name: description, dtype: object
# 290    print adour btm adour slightli scoop lowris fr...
# 218    solid adour btm adour featur scoop lowris fron...
# Name: description, dtype: object
# 292    houdini fullzip jkt see dont like sun blusteri...
# 404    houdini fullzip jkt see dont like sun blusteri...
# Name: description, dtype: object
# 304    intercontinent pant reg youll like flatter dra...
# 187    intercontinent pant long youll like flatter dr...
# Name: description, dtype: object
# 307    alpin wind jkt high ridg steep ice anyth alpin...
# 4      alpin wind jkt high ridg steep ice anyth alpin...
# Name: description, dtype: object
# 326    torrentshel jkt tropic rain forest share least...
# 273    torrentshel jkt tropic rain forest share least...
# Name: description, dtype: object
# 333    live simpli deer tshirt adapt simpli matter su...
# 71     live simpli deer tshirt adapt simpli matter su...
# Name: description, dtype: object
# 334    live simpli guitar tshirt live life unplug lig...
# 72     live simpli guitar tshirt live life unplug tee...
# Name: description, dtype: object
# 347    runshad tshirt there long trail ahead your gel...
# 244    runshad tshirt backcountri anyplac move comfor...
# Name: description, dtype: object
# 349    shop pant long home truck insid shop pant made...
# 117    shop pant reg home truck insid shop pant made ...
# Name: description, dtype: object
# 349    shop pant long home truck insid shop pant made...
# 118    shop pant short home truck insid shop pant mad...
# Name: description, dtype: object
# 350    rain shadow pant light enough afterthought dow...
# 106    rain shadow pant light enough afterthought dow...
# Name: description, dtype: object
# 354    watermast wader king blackberri barbwir basalt...
# 152    watermast wader long blackberri barbwir basalt...
# Name: description, dtype: object
# 354    watermast wader king blackberri barbwir basalt...
# 153    watermast wader short blackberri barbwir basal...
# Name: description, dtype: object
# 354    watermast wader king blackberri barbwir basalt...
# 366    watermast wader reg blackberri barbwir basaltt...
# Name: description, dtype: object
# 358    cap cap sleev fastestdri perform baselay fabri...
# 359    cap tshirt like sweet breez long run hot day c...
# Name: description, dtype: object
# 359    cap tshirt like sweet breez long run hot day c...
# 358    cap cap sleev fastestdri perform baselay fabri...
# Name: description, dtype: object
# 360    ss rashguard upf fabric shortsleev rashguard k...
# 76     ls rashguard upf fabric longsleev rashguard ke...
# Name: description, dtype: object
# 363    nine trail vest simplic action vest protect co...
# 209    nine trail vest simplic action vest protect co...
# Name: description, dtype: object
# 366    watermast wader reg blackberri barbwir basaltt...
# 152    watermast wader long blackberri barbwir basalt...
# Name: description, dtype: object
# 366    watermast wader reg blackberri barbwir basaltt...
# 153    watermast wader short blackberri barbwir basal...
# Name: description, dtype: object
# 366    watermast wader reg blackberri barbwir basaltt...
# 354    watermast wader king blackberri barbwir basalt...
# Name: description, dtype: object
# 368    stand short theyv around plu year reenvis rein...
# 369    stand short theyv around plu year reenvis rein...
# Name: description, dtype: object
# 369    stand short theyv around plu year reenvis rein...
# 368    stand short theyv around plu year reenvis rein...
# Name: description, dtype: object
# 377    r fullzip jkt stretch breath wick warm wonder ...
# 262    r fullzip jkt stretch breath wick warm wonder ...
# Name: description, dtype: object
# 378    lw guid pant backcountri version immens popula...
# 383    lw guid pant backcountri version immens popula...
# Name: description, dtype: object
# 379    lw r jkt high deck warbonnet peak immacul wind...
# 81     lw r jkt high deck warbonnet peak immacul wind...
# Name: description, dtype: object
# 380    r jkt modern mountain stapl adapt r jacket ser...
# 210    r jkt modern mountain stapl adapt r jacket ser...
# Name: description, dtype: object
# 381    rain shadow jkt stay insid isnt way stay dri e...
# 211    rain shadow jkt stay insid isnt way stay dri e...
# Name: description, dtype: object
# 383    lw guid pant backcountri version immens popula...
# 378    lw guid pant backcountri version immens popula...
# Name: description, dtype: object
# 385    storm light jkt emerg classic inspir origin st...
# 266    storm light jkt emerg classic inspir origin st...
# Name: description, dtype: object
# 386    stretch ascent jkt simpl stretchi lightweight ...
# 267    stretch ascent jkt simpl stretchi lightweight ...
# Name: description, dtype: object
# 389    reg fit organ ctn jeansshort organ cotton deni...
# 107    reg fit organ ctn jeanslong organ cotton denim...
# Name: description, dtype: object
# 389    reg fit organ ctn jeansshort organ cotton deni...
# 108    reg fit organ ctn jeansreg organ cotton denim ...
# Name: description, dtype: object
# 390    relax fit organ ctn jeanslong everyday goto ra...
# 109    relax fit organ ctn jeansshor everyday goto ra...
# Name: description, dtype: object
# 390    relax fit organ ctn jeanslong everyday goto ra...
# 391    relax fit organ ctn jeansreg everyday goto rar...
# Name: description, dtype: object
# 391    relax fit organ ctn jeansreg everyday goto rar...
# 109    relax fit organ ctn jeansshor everyday goto ra...
# Name: description, dtype: object
# 391    relax fit organ ctn jeansreg everyday goto rar...
# 390    relax fit organ ctn jeanslong everyday goto ra...
# Name: description, dtype: object
# 404    houdini fullzip jkt see dont like sun blusteri...
# 292    houdini fullzip jkt see dont like sun blusteri...
# Name: description, dtype: object
# 405    merino bottom stopandgo pace like alpin climb ...
# 265    merino bottom thank dri warm forward progress ...
# Name: description, dtype: object
# 406    merino crew soft longsleev tee work sweat bike...
# 89     merino tshirt stay calm collect amid frenzi na...
# Name: description, dtype: object
# 415    micro puff vest mani alpin shiverfest leav mum...
# 203    micro puff vest mani alpin shiverfest leav mum...
# Name: description, dtype: object
# 419    riverwalk sticki high water slick bedrock cobb...
# 112    riverwalk felt high water slick bedrock cobbl ...
# Name: description, dtype: object
# 419    riverwalk sticki high water slick bedrock cobb...
# 113    riverwalk stud high water slick bedrock cobbl ...
# Name: description, dtype: object
# 431    girl live simpli deer tshirt softwear ringspun...
# 57     logo tshirt softwear ringspun organ cotton scr...
# Name: description, dtype: object
# 431    girl live simpli deer tshirt softwear ringspun...
# 62     fli fish tshirt softwear ringspun organ cotton...
# Name: description, dtype: object
# 431    girl live simpli deer tshirt softwear ringspun...
# 64     live simpli guitar tshirt softwear ringspun or...
# Name: description, dtype: object
# 431    girl live simpli deer tshirt softwear ringspun...
# 432    girl live simpli seal tshirt softwear ringspun...
# Name: description, dtype: object
# 432    girl live simpli seal tshirt softwear ringspun...
# 57     logo tshirt softwear ringspun organ cotton scr...
# Name: description, dtype: object
# 432    girl live simpli seal tshirt softwear ringspun...
# 62     fli fish tshirt softwear ringspun organ cotton...
# Name: description, dtype: object
# 432    girl live simpli seal tshirt softwear ringspun...
# 64     live simpli guitar tshirt softwear ringspun or...
# Name: description, dtype: object
# 432    girl live simpli seal tshirt softwear ringspun...
# 431    girl live simpli deer tshirt softwear ringspun...
# Name: description, dtype: object
# 437    guid jkt sharp granit sticki vergla untrack li...
# 183    guid jkt sharp granit sticki vergla untrack li...
# Name: description, dtype: object
# 440    cap crew capilen versatil fastestwick perform ...
# 442    cap crew fundament funhog lifestyl crew noncha...
# Name: description, dtype: object
# 442    cap crew fundament funhog lifestyl crew noncha...
# 440    cap crew capilen versatil fastestwick perform ...
# Name: description, dtype: object
# 451    compound cargo pant short ultim doeveryth pant...
# 26     compound cargo pant long ultim doeveryth pant ...
# Name: description, dtype: object
# 451    compound cargo pant short ultim doeveryth pant...
# 27     compound cargo pant reg ultim doeveryth pant b...
# Name: description, dtype: object
# 454    guidewat wader king built guidewat wader tough...
# 467    guidewat wader reg built guidewat wader toughe...
# Name: description, dtype: object
# 455    critic mass built twowheel commut critic mass ...
# 485    half mass size ride bike fine tune hold day wo...
# Name: description, dtype: object
# 457    nano puff po alreadi cult classic ambassador t...
# 279    nano puff po versatil piec insul make nano puf...
# Name: description, dtype: object
# 461    custodian pant reg graveyard shift advantag qu...
# 31     custodian pant long graveyard shift advantag q...
# Name: description, dtype: object
# 461    custodian pant reg graveyard shift advantag qu...
# 462    custodian pant short graveyard shift advantag ...
# Name: description, dtype: object
# 462    custodian pant short graveyard shift advantag ...
# 31     custodian pant long graveyard shift advantag q...
# Name: description, dtype: object
# 462    custodian pant short graveyard shift advantag ...
# 461    custodian pant reg graveyard shift advantag qu...
# Name: description, dtype: object
# 467    guidewat wader reg built guidewat wader toughe...
# 454    guidewat wader king built guidewat wader tough...
# Name: description, dtype: object
# 472    sweater there much see feet chasm view bivi ve...
# 178    sweater there much see feet chasm view bivi ve...
# Name: description, dtype: object
# 480    duck pant reg essenti wear split log drive nai...
# 36     duck pant long essenti wear split log drive na...
# Name: description, dtype: object
# 480    duck pant reg essenti wear split log drive nai...
# 481    duck pant short essenti wear split log drive n...
# Name: description, dtype: object
# 481    duck pant short essenti wear split log drive n...
# 36     duck pant long essenti wear split log drive na...
# Name: description, dtype: object
# 481    duck pant short essenti wear split log drive n...
# 480    duck pant reg essenti wear split log drive nai...
# Name: description, dtype: object
# 485    half mass size ride bike fine tune hold day wo...
# 455    critic mass built twowheel commut critic mass ...
# Name: description, dtype: object
# 491    freedom roam tshirt global warm habitat destru...
# 285    freedom roam tshirt global warm habitat destru...
# Name: description, dtype: object

# %% [markdown]
# # WORD2VEC

# %%
# Загружаем предобученную модель
word_vectors = gensim.downloader.load("word2vec-google-news-300")

# %%
# Создаем пустой DataFrame для эмбедингов текстов
docs_vectors = pd.DataFrame()

# Идем по текстам
for doc in data['description']:
    
    # Создаем пустой DataFrame для хранения векторов слов текста
    temp = pd.DataFrame()
    
    # Идем по словам в тексте
    for word in doc.split(' '):
        
        try:
            # Векторизуем слово с использованием предобученной модели W2V
            word_vec = word_vectors[word]

            # Добавляем вектор слова в DF
            temp = temp.append(pd.Series(word_vec), ignore_index = True)
            
        except:
            pass
        
    # Вычисляем вектор текста усредняя массив векторов слов
    doc_vector = temp.mean()
    
    # Добавляем вектор текста в DF эмбедингов текстов
    docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)

# Размерность DF эмбедингов текстов    
docs_vectors.shape
# Out:
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# ...
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series(word_vec), ignore_index = True)
# C:\Users\a_l_b\AppData\Local\Temp\ipykernel_15904\3738768034.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)
# (500, 300)

# %%
# Примеры векторизованных текстов
docs_vectors.sample(5)
# Out:
#           0         1         2         3         4         5         6    \
# 246 -0.010637  0.036027 -0.022741  0.091949 -0.103591  0.002241  0.046943
# 134 -0.064471  0.072878  0.005432 -0.015769 -0.090759 -0.022298  0.058849
# 256 -0.002893  0.029724 -0.024451  0.068431 -0.067511 -0.008963  0.065377
# 363 -0.018240  0.052597 -0.001162  0.038519 -0.051881 -0.015857  0.014083
# 243 -0.061320  0.048766 -0.029659  0.056129 -0.049346 -0.065844  0.032107
#
#           7         8         9    ...       290       291       292  \
# 246 -0.115362  0.042649  0.043243  ... -0.094710 -0.018391 -0.059907
# 134 -0.086650  0.061625  0.082275  ... -0.057861  0.041439 -0.068804
# 256 -0.083518  0.077112  0.072567  ... -0.026885  0.027326 -0.066785
# 363 -0.095194  0.094443  0.094764  ... -0.031378  0.011135 -0.090970
# 243 -0.113993  0.011851  0.109122  ... -0.023781  0.034406 -0.049840
#
#           293       294       295       296       297       298       299
# 246 -0.081540  0.016225 -0.050821  0.029154  0.019330  0.015523  0.043067
# 134  0.009345 -0.035520 -0.066657  0.048324 -0.030881 -0.011342  0.001026
# 256  0.017181 -0.032571 -0.037747  0.021783 -0.056830  0.019538  0.017740
# 363  0.047584 -0.034989 -0.071136  0.062725  0.005143  0.042340  0.013738
# 243  0.029876 -0.035379 -0.062105  0.064212 -0.018301 -0.003701 -0.028966
#
# [5 rows x 300 columns]

# %%
# Вычисляем попарно косинусное расстояние между векторами в матрице, округляем значения до 5 знака после запятой
cos_matrix_w2v = np.around(cosine_similarity(docs_vectors), 5)
cos_matrix_w2v
# Out:
# array([[1.     , 0.89715, 0.82771, ..., 0.8083 , 0.83906, 0.84815],
#        [0.89715, 1.     , 0.92409, ..., 0.85416, 0.87068, 0.86517],
#        [0.82771, 0.92409, 1.     , ..., 0.82518, 0.81348, 0.81482],
#        ...,
#        [0.8083 , 0.85416, 0.82518, ..., 1.     , 0.86359, 0.81589],
#        [0.83906, 0.87068, 0.81348, ..., 0.86359, 1.     , 0.94493],
#        [0.84815, 0.86517, 0.81482, ..., 0.81589, 0.94493, 1.     ]],
#       dtype=float32)

# %%
# Находим пары векторов, косинусное расстояние между которыми больше 0.95
pair_indexes_w2v = np.transpose(np.nonzero(cos_matrix_w2v > 0.95))

# Перебираем пары индексов
for x in pair_indexes_w2v:
    
    # Если индексы не равны друг другу, что означает, что сравнивались описания разных товаров
    if x[0] != x[1]:
        
        # Выводим пары похожих описаний товаров
        print(df['description'][x])
# Out:
# 3      alpin guid pant skin climb ice switch rock tra...
# 158    alpin guid pant skin climb ice switch rock tra...
# Name: description, dtype: object
# 3      alpin guid pant skin climb ice switch rock tra...
# 212    rock guid pant rock guid made soft stretchwove...
# Name: description, dtype: object
# 3      alpin guid pant skin climb ice switch rock tra...
# 330    travers pant stride lightli juan tabo picnic a...
# Name: description, dtype: object
# 3      alpin guid pant skin climb ice switch rock tra...
# 342    rock guid pant first foremost lightweight soft...
# Name: description, dtype: object
# 3      alpin guid pant skin climb ice switch rock tra...
# 352    simpl guid pant stapl rock ice mix climb sprin...
# Name: description, dtype: object
# 3      alpin guid pant skin climb ice switch rock tra...
# 378    lw guid pant backcountri version immens popula...
# Name: description, dtype: object
# 3      alpin guid pant skin climb ice switch rock tra...
# 383    lw guid pant backcountri version immens popula...
# Name: description, dtype: object
# 4      alpin wind jkt high ridg steep ice anyth alpin...
# 307    alpin wind jkt high ridg steep ice anyth alpin...
# Name: description, dtype: object
# 5      ascensionist jkt technic soft shell fullon mou...
# 437    guid jkt sharp granit sticki vergla untrack li...
# Name: description, dtype: object
# 6      atom multitask cloud nine atom play part couri...
# 353    singl shot singl shot organ daili necess thoug...
# Name: description, dtype: object
# 6      atom multitask cloud nine atom play part couri...
# 392    lw travel sling feel openend like good itinera...
# Name: description, dtype: object
# 6      atom multitask cloud nine atom play part couri...
# 463    daili grind fulli pad shoulder bag keep move u...
# Name: description, dtype: object
# 7      print band betina btm fullest coverag bottom b...
# 219    solid betina btm fullest coverag bottom betina...
# Name: description, dtype: object
# 7      print band betina btm fullest coverag bottom b...
# 254    solid suname btm stayput suname fit straight a...
# Name: description, dtype: object
# 7      print band betina btm fullest coverag bottom b...
# 261    print suname btm stayput suname fit straight a...
# Name: description, dtype: object
# 11     baggi short even baggi popular short anyth not...
# 305    intercontinent short time ascent iren aret rig...
# Name: description, dtype: object
# 11     baggi short even baggi popular short anyth not...
# 401    river short river life mighti fine even occasi...
# Name: description, dtype: object
# 14    borderless short go forward other cring border...
# 15    borderless short one summertim gift chanc free...
# Name: description, dtype: object
# 14    borderless short go forward other cring border...
# 58    borderless gi short short mud sand grassresist...
# Name: description, dtype: object
# 14     borderless short go forward other cring border...
# 114    rock guid short made high open expans granit l...
# Name: description, dtype: object
# 14     borderless short go forward other cring border...
# 167    borderless capri unfaz gloppi spindrift border...
# Name: description, dtype: object
# 14     borderless short go forward other cring border...
# 208    nine trail short mountain bike trail run fast ...
# Name: description, dtype: object
# 14     borderless short go forward other cring border...
# 327    borderless pant borderless pant wont hem quest...
# Name: description, dtype: object
# 14     borderless short go forward other cring border...
# 328    borderless short borderless short prefer push ...
# Name: description, dtype: object
# 14     borderless short go forward other cring border...
# 479    borderless messeng short pair lightweight stre...
# Name: description, dtype: object
# 14     borderless short go forward other cring border...
# 483    borderless trek pant rubi crest trail run two ...
# Name: description, dtype: object
# 14     borderless short go forward other cring border...
# 484    borderless trek zipoff pant made technic perfo...
# Name: description, dtype: object
# 15    borderless short one summertim gift chanc free...
# 14    borderless short go forward other cring border...
# Name: description, dtype: object
# 15    borderless short one summertim gift chanc free...
# 58    borderless gi short short mud sand grassresist...
# Name: description, dtype: object
# 15     borderless short one summertim gift chanc free...
# 114    rock guid short made high open expans granit l...
# Name: description, dtype: object
# 15     borderless short one summertim gift chanc free...
# 479    borderless messeng short pair lightweight stre...
# Name: description, dtype: object
# 15     borderless short one summertim gift chanc free...
# 483    borderless trek pant rubi crest trail run two ...
# Name: description, dtype: object
# 15     borderless short one summertim gift chanc free...
# 484    borderless trek zipoff pant made technic perfo...
# Name: description, dtype: object
# 17     cap bottom spring ski transient wind move fast...
# 170    cap bottom made lightestweight capilen baselay...
# Name: description, dtype: object
# 17     cap bottom spring ski transient wind move fast...
# 171    cap tshirt good breez calm swelter tempest sil...
# Name: description, dtype: object
# 18     cap boxer brief bivi belay formfit capilen box...
# 493    activ boxer brief nofuss travel companion skiv...
# Name: description, dtype: object
# 19    cap graphic tshirt tee made lightestweight cap...
# 20    cap tshirt minim style technic evolv punish ex...
# Name: description, dtype: object
# 19     cap graphic tshirt tee made lightestweight cap...
# 171    cap tshirt good breez calm swelter tempest sil...
# Name: description, dtype: object
# 19     cap graphic tshirt tee made lightestweight cap...
# 339    cap graphic tshirt eleg union grace design tec...
# Name: description, dtype: object
# 19     cap graphic tshirt tee made lightestweight cap...
# 340    cap scoop silki top design desert run fastforw...
# Name: description, dtype: object
# 19     cap graphic tshirt tee made lightestweight cap...
# 486    cap crew come moistur longsleev tee seriou con...
# Name: description, dtype: object
# 19     cap graphic tshirt tee made lightestweight cap...
# 487    cap graphic crew choic rest day includ ultim f...
# Name: description, dtype: object
# 20    cap tshirt minim style technic evolv punish ex...
# 19    cap graphic tshirt tee made lightestweight cap...
# Name: description, dtype: object
# 20     cap tshirt minim style technic evolv punish ex...
# 171    cap tshirt good breez calm swelter tempest sil...
# Name: description, dtype: object
# 20     cap tshirt minim style technic evolv punish ex...
# 339    cap graphic tshirt eleg union grace design tec...
# Name: description, dtype: object
# 20     cap tshirt minim style technic evolv punish ex...
# 486    cap crew come moistur longsleev tee seriou con...
# Name: description, dtype: object
# 20     cap tshirt minim style technic evolv punish ex...
# 487    cap graphic crew choic rest day includ ultim f...
# Name: description, dtype: object
# 21    cap tshirt one revel sweat jambore hill climb ...
# 22    cap zip neck design wetthenchil pursuit like b...
# Name: description, dtype: object
# 21     cap tshirt one revel sweat jambore hill climb ...
# 172    cap bottom simulclimb final pitch beat descend...
# Name: description, dtype: object
# 21     cap tshirt one revel sweat jambore hill climb ...
# 173    cap vneck climber choic capilen fabric manag m...
# Name: description, dtype: object
# 21     cap tshirt one revel sweat jambore hill climb ...
# 174    cap zip neck bugaboo long approach make sweati...
# Name: description, dtype: object
# 21     cap tshirt one revel sweat jambore hill climb ...
# 358    cap cap sleev fastestdri perform baselay fabri...
# Name: description, dtype: object
# 21     cap tshirt one revel sweat jambore hill climb ...
# 359    cap tshirt like sweet breez long run hot day c...
# Name: description, dtype: object
# 21     cap tshirt one revel sweat jambore hill climb ...
# 495    cap bottom cut loos madden crowd search undon ...
# Name: description, dtype: object
# 21     cap tshirt one revel sweat jambore hill climb ...
# 496    cap crew crew take edg fickl weather clear con...
# Name: description, dtype: object
# 22    cap zip neck design wetthenchil pursuit like b...
# 21    cap tshirt one revel sweat jambore hill climb ...
# Name: description, dtype: object
# 22     cap zip neck design wetthenchil pursuit like b...
# 173    cap vneck climber choic capilen fabric manag m...
# Name: description, dtype: object
# 22     cap zip neck design wetthenchil pursuit like b...
# 174    cap zip neck bugaboo long approach make sweati...
# Name: description, dtype: object
# 22     cap zip neck design wetthenchil pursuit like b...
# 276    cap zip neck keep furnac stoke temperatur nose...
# Name: description, dtype: object
# 22     cap zip neck design wetthenchil pursuit like b...
# 358    cap cap sleev fastestdri perform baselay fabri...
# Name: description, dtype: object
# 22     cap zip neck design wetthenchil pursuit like b...
# 359    cap tshirt like sweet breez long run hot day c...
# Name: description, dtype: object
# 22     cap zip neck design wetthenchil pursuit like b...
# 495    cap bottom cut loos madden crowd search undon ...
# Name: description, dtype: object
# 22     cap zip neck design wetthenchil pursuit like b...
# 496    cap crew crew take edg fickl weather clear con...
# Name: description, dtype: object
# 23     cap zip neck capilen provid excel insul nextto...
# 439    cap bottom unwav foundat coldweath cloth syste...
# Name: description, dtype: object
# 23     cap zip neck capilen provid excel insul nextto...
# 440    cap crew capilen versatil fastestwick perform ...
# Name: description, dtype: object
# 23     cap zip neck capilen provid excel insul nextto...
# 441    cap bottom ice climber alpinist know pitfal sw...
# Name: description, dtype: object
# 23     cap zip neck capilen provid excel insul nextto...
# 442    cap crew fundament funhog lifestyl crew noncha...
# Name: description, dtype: object
# 24     cap bottom sufferfest like grand januari pair ...
# 175    cap bottom world consist granit frozen place c...
# Name: description, dtype: object
# 24     cap bottom sufferfest like grand januari pair ...
# 276    cap zip neck keep furnac stoke temperatur nose...
# Name: description, dtype: object
# 24     cap bottom sufferfest like grand januari pair ...
# 439    cap bottom unwav foundat coldweath cloth syste...
# Name: description, dtype: object
# 24     cap bottom sufferfest like grand januari pair ...
# 445    cap zip neck warmest synthet baselay deep free...
# Name: description, dtype: object
# 25    citi sea tshirt illustr renaiss seainspir comm...
# 35    dragoon tshirt dragoon drop weapon favor big w...
# Name: description, dtype: object
# 25    citi sea tshirt illustr renaiss seainspir comm...
# 40    fish frenzi tshirt depend freeflow current sal...
# Name: description, dtype: object
# 25    citi sea tshirt illustr renaiss seainspir comm...
# 55    iceberg tshirt effect global warm run deep dep...
# Name: description, dtype: object
# 25    citi sea tshirt illustr renaiss seainspir comm...
# 70    live simpli bug tshirt natur live organ eventu...
# Name: description, dtype: object
# 25    citi sea tshirt illustr renaiss seainspir comm...
# 72    live simpli guitar tshirt live life unplug tee...
# Name: description, dtype: object
# 25    citi sea tshirt illustr renaiss seainspir comm...
# 97    organ logo tshirt origin print first season de...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 101    planer tshirt planer tshirt give nod surf work...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 115    rockpil tshirt beauti boulder stack togeth roc...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 123    squid tshirt artist tim tompkinson origin work...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 137    text logo tshirt text logo tshirt tell classic...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 138    know tshirt inspir thoreau immort word yvon ch...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 143    trout silhouett tshirt simplic silhouett tshir...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 166    birdwalk tshirt temporarili ground artist chri...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 169    butterfli logo tshirt like monarch butterfli l...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 177    ditch carrid tshirt fun get enjoy ride ditch c...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 184    hill tshirt head hill wear simplydesign hill t...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 236    wheat tshirt feed urban agrarian sensibl wheat...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 238    yosemit essenc tshirt artist phylli shafer gor...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 275    trampoli tshirt take commut higher ground tram...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 288    owlin around tshirt owlin around tshirt wise c...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 314    kite town tshirt artist chri del moro transfor...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 321    tarpon tshirt channel determin silver king wea...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 334    live simpli guitar tshirt live life unplug lig...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 346    vintag logo pkt tshirt keep downlow classic vi...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 371    peregrin tshirt born wander onceendang peregri...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 372    permit silhouett tshirt permit scytheshap dors...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 396    wind path tshirt visual energi wind path tshir...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 422    futur earth tshirt planet futur question answe...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 447    cerro torr one tshirt intermin spirit cerro to...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 466    babi circu tshirt anim savanna work togeth inf...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 469    babi live simpli deer tshirt live simpli deer ...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 470    babi live simpli seal tshirt swim fish haul si...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 490    fli fish tshirt life color flyingfish tshirt f...
# Name: description, dtype: object
# 25     citi sea tshirt illustr renaiss seainspir comm...
# 492    logo tshirt patagonia timeless logo tshirt pay...
# Name: description, dtype: object
# 26    compound cargo pant long ultim doeveryth pant ...
# 27    compound cargo pant reg ultim doeveryth pant b...
# Name: description, dtype: object
# 26     compound cargo pant long ultim doeveryth pant ...
# 451    compound cargo pant short ultim doeveryth pant...
# Name: description, dtype: object
# 26     compound cargo pant long ultim doeveryth pant ...
# 452    compound cargo short cargo pocket pull vintag ...
# Name: description, dtype: object
# 27    compound cargo pant reg ultim doeveryth pant b...
# 26    compound cargo pant long ultim doeveryth pant ...
# Name: description, dtype: object
# 27     compound cargo pant reg ultim doeveryth pant b...
# 451    compound cargo pant short ultim doeveryth pant...
# Name: description, dtype: object
# 27     compound cargo pant reg ultim doeveryth pant b...
# 452    compound cargo short cargo pocket pull vintag ...
# Name: description, dtype: object
# 28     continent short wrinkleresist travel short gre...
# 453    continent pant go straight cramp corner pack b...
# Name: description, dtype: object
# 30     crosstown crosstown crosscountri fulli featur ...
# 353    singl shot singl shot organ daili necess thoug...
# Name: description, dtype: object
# 30     crosstown crosstown crosscountri fulli featur ...
# 435    lightwir sometim need leav offic rearview mirr...
# Name: description, dtype: object
# 30     crosstown crosstown crosscountri fulli featur ...
# 436    lightwir brief adventur briefcas hold boulder ...
# Name: description, dtype: object
# 30     crosstown crosstown crosscountri fulli featur ...
# 455    critic mass built twowheel commut critic mass ...
# Name: description, dtype: object
# 30     crosstown crosstown crosscountri fulli featur ...
# 463    daili grind fulli pad shoulder bag keep move u...
# Name: description, dtype: object
# 31    custodian pant long graveyard shift advantag q...
# 33    deliveri short local know best spot deliveri s...
# Name: description, dtype: object
# 31     custodian pant long graveyard shift advantag q...
# 461    custodian pant reg graveyard shift advantag qu...
# Name: description, dtype: object
# 31     custodian pant long graveyard shift advantag q...
# 462    custodian pant short graveyard shift advantag ...
# Name: description, dtype: object
# 31     custodian pant long graveyard shift advantag q...
# 499    allwear short time simplifi allwear short prov...
# Name: description, dtype: object
# 32    deep wade jkt whether your chase olymp peninsu...
# 50    guidewat jkt pound teeth noreast swing tip del...
# Name: description, dtype: object
# 32     deep wade jkt whether your chase olymp peninsu...
# 128    sst jkt bristol bay tierra del fuego russian a...
# Name: description, dtype: object
# 33    deliveri short local know best spot deliveri s...
# 31    custodian pant long graveyard shift advantag q...
# Name: description, dtype: object
# 33     deliveri short local know best spot deliveri s...
# 461    custodian pant reg graveyard shift advantag qu...
# Name: description, dtype: object
# 33     deliveri short local know best spot deliveri s...
# 462    custodian pant short graveyard shift advantag ...
# Name: description, dtype: object
# 33     deliveri short local know best spot deliveri s...
# 499    allwear short time simplifi allwear short prov...
# Name: description, dtype: object
# 34     sweater vest imposs confus sweater vest found ...
# 178    sweater there much see feet chasm view bivi ve...
# Name: description, dtype: object
# 34     sweater vest imposs confus sweater vest found ...
# 203    micro puff vest mani alpin shiverfest leav mum...
# Name: description, dtype: object
# 34     sweater vest imposs confus sweater vest found ...
# 281    sweater vest imposs confus sweater vest found ...
# Name: description, dtype: object
# 34     sweater vest imposs confus sweater vest found ...
# 415    micro puff vest mani alpin shiverfest leav mum...
# Name: description, dtype: object
# 34     sweater vest imposs confus sweater vest found ...
# 472    sweater there much see feet chasm view bivi ve...
# Name: description, dtype: object
# 35    dragoon tshirt dragoon drop weapon favor big w...
# 25    citi sea tshirt illustr renaiss seainspir comm...
# Name: description, dtype: object
# 35    dragoon tshirt dragoon drop weapon favor big w...
# 40    fish frenzi tshirt depend freeflow current sal...
# Name: description, dtype: object
# 35     dragoon tshirt dragoon drop weapon favor big w...
# 101    planer tshirt planer tshirt give nod surf work...
# Name: description, dtype: object
# 35     dragoon tshirt dragoon drop weapon favor big w...
# 115    rockpil tshirt beauti boulder stack togeth roc...
# Name: description, dtype: object
# 35     dragoon tshirt dragoon drop weapon favor big w...
# 169    butterfli logo tshirt like monarch butterfli l...
# Name: description, dtype: object
# 35     dragoon tshirt dragoon drop weapon favor big w...
# 177    ditch carrid tshirt fun get enjoy ride ditch c...
# Name: description, dtype: object
# 35     dragoon tshirt dragoon drop weapon favor big w...
# 184    hill tshirt head hill wear simplydesign hill t...
# Name: description, dtype: object
# 35     dragoon tshirt dragoon drop weapon favor big w...
# 238    yosemit essenc tshirt artist phylli shafer gor...
# Name: description, dtype: object
# 35     dragoon tshirt dragoon drop weapon favor big w...
# 275    trampoli tshirt take commut higher ground tram...
# Name: description, dtype: object
# 35     dragoon tshirt dragoon drop weapon favor big w...
# 288    owlin around tshirt owlin around tshirt wise c...
# Name: description, dtype: object
# 35     dragoon tshirt dragoon drop weapon favor big w...
# 314    kite town tshirt artist chri del moro transfor...
# Name: description, dtype: object
# 35     dragoon tshirt dragoon drop weapon favor big w...
# 321    tarpon tshirt channel determin silver king wea...
# Name: description, dtype: object
# 35     dragoon tshirt dragoon drop weapon favor big w...
# 371    peregrin tshirt born wander onceendang peregri...
# Name: description, dtype: object
# 35     dragoon tshirt dragoon drop weapon favor big w...
# 396    wind path tshirt visual energi wind path tshir...
# Name: description, dtype: object
# 35     dragoon tshirt dragoon drop weapon favor big w...
# 490    fli fish tshirt life color flyingfish tshirt f...
# Name: description, dtype: object
# 36     duck pant long essenti wear split log drive na...
# 480    duck pant reg essenti wear split log drive nai...
# Name: description, dtype: object
# 36     duck pant long essenti wear split log drive na...
# 481    duck pant short essenti wear split log drive n...
# Name: description, dtype: object
# 36     duck pant long essenti wear split log drive na...
# 482    duck short sometim life requir welder time rea...
# Name: description, dtype: object
# 40    fish frenzi tshirt depend freeflow current sal...
# 25    citi sea tshirt illustr renaiss seainspir comm...
# Name: description, dtype: object
# 40    fish frenzi tshirt depend freeflow current sal...
# 35    dragoon tshirt dragoon drop weapon favor big w...
# Name: description, dtype: object
# 40    fish frenzi tshirt depend freeflow current sal...
# 55    iceberg tshirt effect global warm run deep dep...
# Name: description, dtype: object
# 40    fish frenzi tshirt depend freeflow current sal...
# 70    live simpli bug tshirt natur live organ eventu...
# Name: description, dtype: object
# 40    fish frenzi tshirt depend freeflow current sal...
# 71    live simpli deer tshirt adapt simpli matter su...
# Name: description, dtype: object
# 40    fish frenzi tshirt depend freeflow current sal...
# 72    live simpli guitar tshirt live life unplug tee...
# Name: description, dtype: object
# 40    fish frenzi tshirt depend freeflow current sal...
# 97    organ logo tshirt origin print first season de...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 101    planer tshirt planer tshirt give nod surf work...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 115    rockpil tshirt beauti boulder stack togeth roc...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 123    squid tshirt artist tim tompkinson origin work...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 138    know tshirt inspir thoreau immort word yvon ch...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 143    trout silhouett tshirt simplic silhouett tshir...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 166    birdwalk tshirt temporarili ground artist chri...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 169    butterfli logo tshirt like monarch butterfli l...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 177    ditch carrid tshirt fun get enjoy ride ditch c...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 184    hill tshirt head hill wear simplydesign hill t...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 236    wheat tshirt feed urban agrarian sensibl wheat...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 238    yosemit essenc tshirt artist phylli shafer gor...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 275    trampoli tshirt take commut higher ground tram...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 287    north coast tshirt north coast tshirt speak da...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 288    owlin around tshirt owlin around tshirt wise c...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 314    kite town tshirt artist chri del moro transfor...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 321    tarpon tshirt channel determin silver king wea...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 332    trout head tshirt vibrant spirit trout captur ...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 333    live simpli deer tshirt adapt simpli matter su...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 371    peregrin tshirt born wander onceendang peregri...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 372    permit silhouett tshirt permit scytheshap dors...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 396    wind path tshirt visual energi wind path tshir...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 422    futur earth tshirt planet futur question answe...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 447    cerro torr one tshirt intermin spirit cerro to...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 466    babi circu tshirt anim savanna work togeth inf...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 469    babi live simpli deer tshirt live simpli deer ...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 470    babi live simpli seal tshirt swim fish haul si...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 490    fli fish tshirt life color flyingfish tshirt f...
# Name: description, dtype: object
# 40     fish frenzi tshirt depend freeflow current sal...
# 492    logo tshirt patagonia timeless logo tshirt pay...
# Name: description, dtype: object
# 41     freewheel sturdi wheel bag hold week worth clo...
# 420    freewheel max like storag locker wheel cavern ...
# Name: description, dtype: object
# 42    gi ii pant traveltest quickdri durabl gi ii pa...
# 43    gi ii short base camp favorit gi ii featherlig...
# Name: description, dtype: object
# 42     gi ii pant traveltest quickdri durabl gi ii pa...
# 114    rock guid short made high open expans granit l...
# Name: description, dtype: object
# 42     gi ii pant traveltest quickdri durabl gi ii pa...
# 213    rock guid short tough abrasionresist rock guid...
# Name: description, dtype: object
# 42     gi ii pant traveltest quickdri durabl gi ii pa...
# 426    gi ii zipoff pant multital gi ii zipoff pant m...
# Name: description, dtype: object
# 43    gi ii short base camp favorit gi ii featherlig...
# 42    gi ii pant traveltest quickdri durabl gi ii pa...
# Name: description, dtype: object
# 43    gi ii short base camp favorit gi ii featherlig...
# 58    borderless gi short short mud sand grassresist...
# Name: description, dtype: object
# 43     gi ii short base camp favorit gi ii featherlig...
# 114    rock guid short made high open expans granit l...
# Name: description, dtype: object
# 43     gi ii short base camp favorit gi ii featherlig...
# 212    rock guid pant rock guid made soft stretchwove...
# Name: description, dtype: object
# 43     gi ii short base camp favorit gi ii featherlig...
# 213    rock guid short tough abrasionresist rock guid...
# Name: description, dtype: object
# 43     gi ii short base camp favorit gi ii featherlig...
# 426    gi ii zipoff pant multital gi ii zipoff pant m...
# Name: description, dtype: object
# 43     gi ii short base camp favorit gi ii featherlig...
# 479    borderless messeng short pair lightweight stre...
# Name: description, dtype: object
# 43     gi ii short base camp favorit gi ii featherlig...
# 484    borderless trek zipoff pant made technic perfo...
# Name: description, dtype: object
# 45     girl boardi short your rais neptun daughter pu...
# 408    boardi short let grom rip tear shred short boa...
# Name: description, dtype: object
# 47    go big bc poster one man trash anoth man treas...
# 68    lead examin life poster guanaco stand sentri p...
# Name: description, dtype: object
# 47     go big bc poster one man trash anoth man treas...
# 237    wyom climb poster max factor c vedauwoo wyom y...
# Name: description, dtype: object
# 47     go big bc poster one man trash anoth man treas...
# 318    symmetri w poster bill serantoni ice climb fea...
# Name: description, dtype: object
# 47     go big bc poster one man trash anoth man treas...
# 489    flyfish athabasca poster patrik ondru wet line...
# Name: description, dtype: object
# 48     great divid stand wave bluewat wind chop there...
# 133    sub divid tough water resist great divid sub c...
# Name: description, dtype: object
# 49     guidewat duffl max seriou angl expedit guidewa...
# 438    guidewat duffl larg whoever said get half fun ...
# Name: description, dtype: object
# 50    guidewat jkt pound teeth noreast swing tip del...
# 32    deep wade jkt whether your chase olymp peninsu...
# Name: description, dtype: object
# 50    guidewat jkt pound teeth noreast swing tip del...
# 52    guidewat vest find tippet tool fli box need wi...
# Name: description, dtype: object
# 50     guidewat jkt pound teeth noreast swing tip del...
# 128    sst jkt bristol bay tierra del fuego russian a...
# Name: description, dtype: object
# 50     guidewat jkt pound teeth noreast swing tip del...
# 444    guidewat shirt shirt jacket itsshacket guidewa...
# Name: description, dtype: object
# 51     guidewat short everyth love guidewat pant less...
# 443    guidewat pant drift boat flat skiff spring cre...
# Name: description, dtype: object
# 52    guidewat vest find tippet tool fli box need wi...
# 50    guidewat jkt pound teeth noreast swing tip del...
# Name: description, dtype: object
# 52     guidewat vest find tippet tool fli box need wi...
# 341    riverwalk vest caddi come thick breath care su...
# Name: description, dtype: object
# 54     hip chest pack readi go vest free classic alte...
# 471    doubl haul sometim need singl fli box clipper ...
# Name: description, dtype: object
# 55    iceberg tshirt effect global warm run deep dep...
# 25    citi sea tshirt illustr renaiss seainspir comm...
# Name: description, dtype: object
# 55    iceberg tshirt effect global warm run deep dep...
# 40    fish frenzi tshirt depend freeflow current sal...
# Name: description, dtype: object
# 55    iceberg tshirt effect global warm run deep dep...
# 97    organ logo tshirt origin print first season de...
# Name: description, dtype: object
# 55     iceberg tshirt effect global warm run deep dep...
# 115    rockpil tshirt beauti boulder stack togeth roc...
# Name: description, dtype: object
# 55     iceberg tshirt effect global warm run deep dep...
# 123    squid tshirt artist tim tompkinson origin work...
# Name: description, dtype: object
# 55     iceberg tshirt effect global warm run deep dep...
# 137    text logo tshirt text logo tshirt tell classic...
# Name: description, dtype: object
# 55     iceberg tshirt effect global warm run deep dep...
# 138    know tshirt inspir thoreau immort word yvon ch...
# Name: description, dtype: object
# 55     iceberg tshirt effect global warm run deep dep...
# 184    hill tshirt head hill wear simplydesign hill t...
# Name: description, dtype: object
# 55     iceberg tshirt effect global warm run deep dep...
# 238    yosemit essenc tshirt artist phylli shafer gor...
# Name: description, dtype: object
# 55     iceberg tshirt effect global warm run deep dep...
# 288    owlin around tshirt owlin around tshirt wise c...
# Name: description, dtype: object
# 55     iceberg tshirt effect global warm run deep dep...
# 371    peregrin tshirt born wander onceendang peregri...
# Name: description, dtype: object
# 55     iceberg tshirt effect global warm run deep dep...
# 447    cerro torr one tshirt intermin spirit cerro to...
# Name: description, dtype: object
# 55     iceberg tshirt effect global warm run deep dep...
# 466    babi circu tshirt anim savanna work togeth inf...
# Name: description, dtype: object
# 55     iceberg tshirt effect global warm run deep dep...
# 490    fli fish tshirt life color flyingfish tshirt f...
# Name: description, dtype: object
# 55     iceberg tshirt effect global warm run deep dep...
# 492    logo tshirt patagonia timeless logo tshirt pay...
# Name: description, dtype: object
# 57    logo tshirt softwear ringspun organ cotton scr...
# 62    fli fish tshirt softwear ringspun organ cotton...
# Name: description, dtype: object
# 57    logo tshirt softwear ringspun organ cotton scr...
# 63    gpiw classic tshirt softwear ringspun organ co...
# Name: description, dtype: object
# 57    logo tshirt softwear ringspun organ cotton scr...
# 64    live simpli guitar tshirt softwear ringspun or...
# Name: description, dtype: object
# 57     logo tshirt softwear ringspun organ cotton scr...
# 431    girl live simpli deer tshirt softwear ringspun...
# Name: description, dtype: object
# 57     logo tshirt softwear ringspun organ cotton scr...
# 432    girl live simpli seal tshirt softwear ringspun...
# Name: description, dtype: object
# 58    borderless gi short short mud sand grassresist...
# 14    borderless short go forward other cring border...
# Name: description, dtype: object
# 58    borderless gi short short mud sand grassresist...
# 15    borderless short one summertim gift chanc free...
# Name: description, dtype: object
# 58    borderless gi short short mud sand grassresist...
# 43    gi ii short base camp favorit gi ii featherlig...
# Name: description, dtype: object
# 58     borderless gi short short mud sand grassresist...
# 114    rock guid short made high open expans granit l...
# Name: description, dtype: object
# 58     borderless gi short short mud sand grassresist...
# 407    baggi short summertim unwind boister flurri ki...
# Name: description, dtype: object
# 58     borderless gi short short mud sand grassresist...
# 479    borderless messeng short pair lightweight stre...
# Name: description, dtype: object
# 58     borderless gi short short mud sand grassresist...
# 483    borderless trek pant rubi crest trail run two ...
# Name: description, dtype: object
# 58     borderless gi short short mud sand grassresist...
# 484    borderless trek zipoff pant made technic perfo...
# Name: description, dtype: object
# 60     cap bottom like bird cloud kid stay move aband...
# 170    cap bottom made lightestweight capilen baselay...
# Name: description, dtype: object
# 60     cap bottom like bird cloud kid stay move aband...
# 172    cap bottom simulclimb final pitch beat descend...
# Name: description, dtype: object
# 62    fli fish tshirt softwear ringspun organ cotton...
# 57    logo tshirt softwear ringspun organ cotton scr...
# Name: description, dtype: object
# 62    fli fish tshirt softwear ringspun organ cotton...
# 63    gpiw classic tshirt softwear ringspun organ co...
# Name: description, dtype: object
# 62    fli fish tshirt softwear ringspun organ cotton...
# 64    live simpli guitar tshirt softwear ringspun or...
# Name: description, dtype: object
# 62     fli fish tshirt softwear ringspun organ cotton...
# 431    girl live simpli deer tshirt softwear ringspun...
# Name: description, dtype: object
# 62     fli fish tshirt softwear ringspun organ cotton...
# 432    girl live simpli seal tshirt softwear ringspun...
# Name: description, dtype: object
# 63    gpiw classic tshirt softwear ringspun organ co...
# 57    logo tshirt softwear ringspun organ cotton scr...
# Name: description, dtype: object
# 63    gpiw classic tshirt softwear ringspun organ co...
# 62    fli fish tshirt softwear ringspun organ cotton...
# Name: description, dtype: object
# 63    gpiw classic tshirt softwear ringspun organ co...
# 64    live simpli guitar tshirt softwear ringspun or...
# Name: description, dtype: object
# 63     gpiw classic tshirt softwear ringspun organ co...
# 431    girl live simpli deer tshirt softwear ringspun...
# Name: description, dtype: object
# 63     gpiw classic tshirt softwear ringspun organ co...
# 432    girl live simpli seal tshirt softwear ringspun...
# Name: description, dtype: object
# 64    live simpli guitar tshirt softwear ringspun or...
# 57    logo tshirt softwear ringspun organ cotton scr...
# Name: description, dtype: object
# 64    live simpli guitar tshirt softwear ringspun or...
# 62    fli fish tshirt softwear ringspun organ cotton...
# Name: description, dtype: object
# 64    live simpli guitar tshirt softwear ringspun or...
# 63    gpiw classic tshirt softwear ringspun organ co...
# Name: description, dtype: object
# 64     live simpli guitar tshirt softwear ringspun or...
# 431    girl live simpli deer tshirt softwear ringspun...
# Name: description, dtype: object
# 64     live simpli guitar tshirt softwear ringspun or...
# 432    girl live simpli seal tshirt softwear ringspun...
# Name: description, dtype: object
# 66    torrentshel jkt barometr pressur get low torre...
# 84    jkt made thrive thin technic climb full alpin ...
# Name: description, dtype: object
# 66     torrentshel jkt barometr pressur get low torre...
# 196    jkt made thrive thin technic climb full alpin ...
# Name: description, dtype: object
# 66     torrentshel jkt barometr pressur get low torre...
# 211    rain shadow jkt stay insid isnt way stay dri e...
# Name: description, dtype: object
# 66     torrentshel jkt barometr pressur get low torre...
# 351    rain shadow trench coat sleek fulllength water...
# Name: description, dtype: object
# 66     torrentshel jkt barometr pressur get low torre...
# 381    rain shadow jkt stay insid isnt way stay dri e...
# Name: description, dtype: object
# 66     torrentshel jkt barometr pressur get low torre...
# 385    storm light jkt emerg classic inspir origin st...
# Name: description, dtype: object
# 66     torrentshel jkt barometr pressur get low torre...
# 423    torrentshel pant torrentshel open world storm ...
# Name: description, dtype: object
# 68    lead examin life poster guanaco stand sentri p...
# 47    go big bc poster one man trash anoth man treas...
# Name: description, dtype: object
# 68     lead examin life poster guanaco stand sentri p...
# 237    wyom climb poster max factor c vedauwoo wyom y...
# Name: description, dtype: object
# 68     lead examin life poster guanaco stand sentri p...
# 318    symmetri w poster bill serantoni ice climb fea...
# Name: description, dtype: object
# 68     lead examin life poster guanaco stand sentri p...
# 331    travers auguil dentrev janin patitucci navig s...
# Name: description, dtype: object
# 68     lead examin life poster guanaco stand sentri p...
# 489    flyfish athabasca poster patrik ondru wet line...
# Name: description, dtype: object
# 70    live simpli bug tshirt natur live organ eventu...
# 25    citi sea tshirt illustr renaiss seainspir comm...
# Name: description, dtype: object
# 70    live simpli bug tshirt natur live organ eventu...
# 40    fish frenzi tshirt depend freeflow current sal...
# Name: description, dtype: object
# 70    live simpli bug tshirt natur live organ eventu...
# 71    live simpli deer tshirt adapt simpli matter su...
# Name: description, dtype: object
# 70    live simpli bug tshirt natur live organ eventu...
# 72    live simpli guitar tshirt live life unplug tee...
# Name: description, dtype: object
# 70     live simpli bug tshirt natur live organ eventu...
# 115    rockpil tshirt beauti boulder stack togeth roc...
# Name: description, dtype: object
# 70     live simpli bug tshirt natur live organ eventu...
# 123    squid tshirt artist tim tompkinson origin work...
# Name: description, dtype: object
# 70     live simpli bug tshirt natur live organ eventu...
# 138    know tshirt inspir thoreau immort word yvon ch...
# Name: description, dtype: object
# 70     live simpli bug tshirt natur live organ eventu...
# 333    live simpli deer tshirt adapt simpli matter su...
# Name: description, dtype: object
# 70     live simpli bug tshirt natur live organ eventu...
# 371    peregrin tshirt born wander onceendang peregri...
# Name: description, dtype: object
# 70     live simpli bug tshirt natur live organ eventu...
# 490    fli fish tshirt life color flyingfish tshirt f...
# Name: description, dtype: object
# 71    live simpli deer tshirt adapt simpli matter su...
# 40    fish frenzi tshirt depend freeflow current sal...
# Name: description, dtype: object
# 71    live simpli deer tshirt adapt simpli matter su...
# 70    live simpli bug tshirt natur live organ eventu...
# Name: description, dtype: object
# 71     live simpli deer tshirt adapt simpli matter su...
# 115    rockpil tshirt beauti boulder stack togeth roc...
# Name: description, dtype: object
# 71     live simpli deer tshirt adapt simpli matter su...
# 138    know tshirt inspir thoreau immort word yvon ch...
# Name: description, dtype: object
# 71     live simpli deer tshirt adapt simpli matter su...
# 332    trout head tshirt vibrant spirit trout captur ...
# Name: description, dtype: object
# 71     live simpli deer tshirt adapt simpli matter su...
# 333    live simpli deer tshirt adapt simpli matter su...
# Name: description, dtype: object
# 71     live simpli deer tshirt adapt simpli matter su...
# 371    peregrin tshirt born wander onceendang peregri...
# Name: description, dtype: object
# 71     live simpli deer tshirt adapt simpli matter su...
# 466    babi circu tshirt anim savanna work togeth inf...
# Name: description, dtype: object
# 71     live simpli deer tshirt adapt simpli matter su...
# 469    babi live simpli deer tshirt live simpli deer ...
# Name: description, dtype: object
# 71     live simpli deer tshirt adapt simpli matter su...
# 490    fli fish tshirt life color flyingfish tshirt f...
# Name: description, dtype: object
# 72    live simpli guitar tshirt live life unplug tee...
# 25    citi sea tshirt illustr renaiss seainspir comm...
# Name: description, dtype: object
# 72    live simpli guitar tshirt live life unplug tee...
# 40    fish frenzi tshirt depend freeflow current sal...
# Name: description, dtype: object
# 72    live simpli guitar tshirt live life unplug tee...
# 70    live simpli bug tshirt natur live organ eventu...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 101    planer tshirt planer tshirt give nod surf work...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 115    rockpil tshirt beauti boulder stack togeth roc...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 138    know tshirt inspir thoreau immort word yvon ch...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 143    trout silhouett tshirt simplic silhouett tshir...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 166    birdwalk tshirt temporarili ground artist chri...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 177    ditch carrid tshirt fun get enjoy ride ditch c...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 184    hill tshirt head hill wear simplydesign hill t...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 238    yosemit essenc tshirt artist phylli shafer gor...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 275    trampoli tshirt take commut higher ground tram...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 287    north coast tshirt north coast tshirt speak da...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 288    owlin around tshirt owlin around tshirt wise c...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 314    kite town tshirt artist chri del moro transfor...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 333    live simpli deer tshirt adapt simpli matter su...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 334    live simpli guitar tshirt live life unplug lig...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 371    peregrin tshirt born wander onceendang peregri...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 372    permit silhouett tshirt permit scytheshap dors...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 396    wind path tshirt visual energi wind path tshir...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 466    babi circu tshirt anim savanna work togeth inf...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 469    babi live simpli deer tshirt live simpli deer ...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 470    babi live simpli seal tshirt swim fish haul si...
# Name: description, dtype: object
# 72     live simpli guitar tshirt live life unplug tee...
# 490    fli fish tshirt life color flyingfish tshirt f...
# Name: description, dtype: object
# 74    ls hood rashguard upf fabric longsleev rashgua...
# 76    ls rashguard upf fabric longsleev rashguard ke...
# Name: description, dtype: object
# 74     ls hood rashguard upf fabric longsleev rashgua...
# 360    ss rashguard upf fabric shortsleev rashguard k...
# Name: description, dtype: object
# 75     ls island hopper shirt seren face seriou heat ...
# 124    ss island hopper shirt seren face seriou heat ...
# Name: description, dtype: object
# 76    ls rashguard upf fabric longsleev rashguard ke...
# 74    ls hood rashguard upf fabric longsleev rashgua...
# Name: description, dtype: object
# 76     ls rashguard upf fabric longsleev rashguard ke...
# 194    ls rashguard upf fabric longsleev rashguard ke...
# Name: description, dtype: object
# 76     ls rashguard upf fabric longsleev rashguard ke...
# 360    ss rashguard upf fabric shortsleev rashguard k...
# Name: description, dtype: object
# 78    lw endur ankl sock fastforward pursuit like ri...
# 79    lw endur quarter sock scrape tape inflam ankl ...
# Name: description, dtype: object
# 78    lw endur ankl sock fastforward pursuit like ri...
# 80    lw hike crew sock like suit feet staycool brea...
# Name: description, dtype: object
# 78     lw endur ankl sock fastforward pursuit like ri...
# 338    ultra lw endur ped sock sock fieri day even sh...
# Name: description, dtype: object
# 79    lw endur quarter sock scrape tape inflam ankl ...
# 78    lw endur ankl sock fastforward pursuit like ri...
# Name: description, dtype: object
# 79    lw endur quarter sock scrape tape inflam ankl ...
# 80    lw hike crew sock like suit feet staycool brea...
# Name: description, dtype: object
# 79     lw endur quarter sock scrape tape inflam ankl ...
# 337    ultra hw mountain sock everi weather window sh...
# Name: description, dtype: object
# 79     lw endur quarter sock scrape tape inflam ankl ...
# 338    ultra lw endur ped sock sock fieri day even sh...
# Name: description, dtype: object
# 79     lw endur quarter sock scrape tape inflam ankl ...
# ...
# 483    borderless trek pant rubi crest trail run two ...
# Name: description, dtype: object
# 485    half mass size ride bike fine tune hold day wo...
# 429    mlc secret slip ohar gauntlet nerv angst reli ...
# Name: description, dtype: object
# 485    half mass size ride bike fine tune hold day wo...
# 435    lightwir sometim need leav offic rearview mirr...
# Name: description, dtype: object
# 485    half mass size ride bike fine tune hold day wo...
# 436    lightwir brief adventur briefcas hold boulder ...
# Name: description, dtype: object
# 485    half mass size ride bike fine tune hold day wo...
# 455    critic mass built twowheel commut critic mass ...
# Name: description, dtype: object
# 485    half mass size ride bike fine tune hold day wo...
# 463    daili grind fulli pad shoulder bag keep move u...
# Name: description, dtype: object
# 486    cap crew come moistur longsleev tee seriou con...
# 19     cap graphic tshirt tee made lightestweight cap...
# Name: description, dtype: object
# 486    cap crew come moistur longsleev tee seriou con...
# 20     cap tshirt minim style technic evolv punish ex...
# Name: description, dtype: object
# 486    cap crew come moistur longsleev tee seriou con...
# 171    cap tshirt good breez calm swelter tempest sil...
# Name: description, dtype: object
# 486    cap crew come moistur longsleev tee seriou con...
# 339    cap graphic tshirt eleg union grace design tec...
# Name: description, dtype: object
# 486    cap crew come moistur longsleev tee seriou con...
# 340    cap scoop silki top design desert run fastforw...
# Name: description, dtype: object
# 486    cap crew come moistur longsleev tee seriou con...
# 487    cap graphic crew choic rest day includ ultim f...
# Name: description, dtype: object
# 487    cap graphic crew choic rest day includ ultim f...
# 19     cap graphic tshirt tee made lightestweight cap...
# Name: description, dtype: object
# 487    cap graphic crew choic rest day includ ultim f...
# 20     cap tshirt minim style technic evolv punish ex...
# Name: description, dtype: object
# 487    cap graphic crew choic rest day includ ultim f...
# 171    cap tshirt good breez calm swelter tempest sil...
# Name: description, dtype: object
# 487    cap graphic crew choic rest day includ ultim f...
# 339    cap graphic tshirt eleg union grace design tec...
# Name: description, dtype: object
# 487    cap graphic crew choic rest day includ ultim f...
# 486    cap crew come moistur longsleev tee seriou con...
# Name: description, dtype: object
# 488    fitz roy studi tshirt unveil fitzroy massif co...
# 166    birdwalk tshirt temporarili ground artist chri...
# Name: description, dtype: object
# 488    fitz roy studi tshirt unveil fitzroy massif co...
# 238    yosemit essenc tshirt artist phylli shafer gor...
# Name: description, dtype: object
# 488    fitz roy studi tshirt unveil fitzroy massif co...
# 275    trampoli tshirt take commut higher ground tram...
# Name: description, dtype: object
# 488    fitz roy studi tshirt unveil fitzroy massif co...
# 287    north coast tshirt north coast tshirt speak da...
# Name: description, dtype: object
# 489    flyfish athabasca poster patrik ondru wet line...
# 47     go big bc poster one man trash anoth man treas...
# Name: description, dtype: object
# 489    flyfish athabasca poster patrik ondru wet line...
# 68     lead examin life poster guanaco stand sentri p...
# Name: description, dtype: object
# 489    flyfish athabasca poster patrik ondru wet line...
# 237    wyom climb poster max factor c vedauwoo wyom y...
# Name: description, dtype: object
# 489    flyfish athabasca poster patrik ondru wet line...
# 318    symmetri w poster bill serantoni ice climb fea...
# Name: description, dtype: object
# 489    flyfish athabasca poster patrik ondru wet line...
# 331    travers auguil dentrev janin patitucci navig s...
# Name: description, dtype: object
# 489    flyfish athabasca poster patrik ondru wet line...
# 370    stick n stone morocco poster patagonia rock am...
# Name: description, dtype: object
# 489    flyfish athabasca poster patrik ondru wet line...
# 395    wild steelhead alaska poster catch releas stee...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 25     citi sea tshirt illustr renaiss seainspir comm...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 35     dragoon tshirt dragoon drop weapon favor big w...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 40     fish frenzi tshirt depend freeflow current sal...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 55     iceberg tshirt effect global warm run deep dep...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 70     live simpli bug tshirt natur live organ eventu...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 71     live simpli deer tshirt adapt simpli matter su...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 72     live simpli guitar tshirt live life unplug tee...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 97     organ logo tshirt origin print first season de...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 101    planer tshirt planer tshirt give nod surf work...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 115    rockpil tshirt beauti boulder stack togeth roc...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 123    squid tshirt artist tim tompkinson origin work...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 137    text logo tshirt text logo tshirt tell classic...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 138    know tshirt inspir thoreau immort word yvon ch...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 143    trout silhouett tshirt simplic silhouett tshir...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 166    birdwalk tshirt temporarili ground artist chri...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 168    bouquet tshirt garland peacock deer mandala gr...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 169    butterfli logo tshirt like monarch butterfli l...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 177    ditch carrid tshirt fun get enjoy ride ditch c...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 184    hill tshirt head hill wear simplydesign hill t...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 236    wheat tshirt feed urban agrarian sensibl wheat...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 238    yosemit essenc tshirt artist phylli shafer gor...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 275    trampoli tshirt take commut higher ground tram...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 288    owlin around tshirt owlin around tshirt wise c...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 314    kite town tshirt artist chri del moro transfor...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 321    tarpon tshirt channel determin silver king wea...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 332    trout head tshirt vibrant spirit trout captur ...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 333    live simpli deer tshirt adapt simpli matter su...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 346    vintag logo pkt tshirt keep downlow classic vi...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 371    peregrin tshirt born wander onceendang peregri...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 372    permit silhouett tshirt permit scytheshap dors...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 396    wind path tshirt visual energi wind path tshir...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 422    futur earth tshirt planet futur question answe...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 447    cerro torr one tshirt intermin spirit cerro to...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 466    babi circu tshirt anim savanna work togeth inf...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 469    babi live simpli deer tshirt live simpli deer ...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 470    babi live simpli seal tshirt swim fish haul si...
# Name: description, dtype: object
# 490    fli fish tshirt life color flyingfish tshirt f...
# 492    logo tshirt patagonia timeless logo tshirt pay...
# Name: description, dtype: object
# 491    freedom roam tshirt global warm habitat destru...
# 285    freedom roam tshirt global warm habitat destru...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 25     citi sea tshirt illustr renaiss seainspir comm...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 40     fish frenzi tshirt depend freeflow current sal...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 55     iceberg tshirt effect global warm run deep dep...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 97     organ logo tshirt origin print first season de...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 115    rockpil tshirt beauti boulder stack togeth roc...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 137    text logo tshirt text logo tshirt tell classic...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 138    know tshirt inspir thoreau immort word yvon ch...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 169    butterfli logo tshirt like monarch butterfli l...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 184    hill tshirt head hill wear simplydesign hill t...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 238    yosemit essenc tshirt artist phylli shafer gor...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 275    trampoli tshirt take commut higher ground tram...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 288    owlin around tshirt owlin around tshirt wise c...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 314    kite town tshirt artist chri del moro transfor...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 332    trout head tshirt vibrant spirit trout captur ...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 346    vintag logo pkt tshirt keep downlow classic vi...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 371    peregrin tshirt born wander onceendang peregri...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 372    permit silhouett tshirt permit scytheshap dors...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 396    wind path tshirt visual energi wind path tshir...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 447    cerro torr one tshirt intermin spirit cerro to...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 466    babi circu tshirt anim savanna work togeth inf...
# Name: description, dtype: object
# 492    logo tshirt patagonia timeless logo tshirt pay...
# 490    fli fish tshirt life color flyingfish tshirt f...
# Name: description, dtype: object
# 493    activ boxer brief nofuss travel companion skiv...
# 18     cap boxer brief bivi belay formfit capilen box...
# Name: description, dtype: object
# 495    cap bottom cut loos madden crowd search undon ...
# 21     cap tshirt one revel sweat jambore hill climb ...
# Name: description, dtype: object
# 495    cap bottom cut loos madden crowd search undon ...
# 22     cap zip neck design wetthenchil pursuit like b...
# Name: description, dtype: object
# 495    cap bottom cut loos madden crowd search undon ...
# 170    cap bottom made lightestweight capilen baselay...
# Name: description, dtype: object
# 495    cap bottom cut loos madden crowd search undon ...
# 172    cap bottom simulclimb final pitch beat descend...
# Name: description, dtype: object
# 495    cap bottom cut loos madden crowd search undon ...
# 173    cap vneck climber choic capilen fabric manag m...
# Name: description, dtype: object
# 495    cap bottom cut loos madden crowd search undon ...
# 174    cap zip neck bugaboo long approach make sweati...
# Name: description, dtype: object
# 495    cap bottom cut loos madden crowd search undon ...
# 358    cap cap sleev fastestdri perform baselay fabri...
# Name: description, dtype: object
# 495    cap bottom cut loos madden crowd search undon ...
# 359    cap tshirt like sweet breez long run hot day c...
# Name: description, dtype: object
# 495    cap bottom cut loos madden crowd search undon ...
# 496    cap crew crew take edg fickl weather clear con...
# Name: description, dtype: object
# 496    cap crew crew take edg fickl weather clear con...
# 21     cap tshirt one revel sweat jambore hill climb ...
# Name: description, dtype: object
# 496    cap crew crew take edg fickl weather clear con...
# 22     cap zip neck design wetthenchil pursuit like b...
# Name: description, dtype: object
# 496    cap crew crew take edg fickl weather clear con...
# 172    cap bottom simulclimb final pitch beat descend...
# Name: description, dtype: object
# 496    cap crew crew take edg fickl weather clear con...
# 173    cap vneck climber choic capilen fabric manag m...
# Name: description, dtype: object
# 496    cap crew crew take edg fickl weather clear con...
# 174    cap zip neck bugaboo long approach make sweati...
# Name: description, dtype: object
# 496    cap crew crew take edg fickl weather clear con...
# 358    cap cap sleev fastestdri perform baselay fabri...
# Name: description, dtype: object
# 496    cap crew crew take edg fickl weather clear con...
# 359    cap tshirt like sweet breez long run hot day c...
# Name: description, dtype: object
# 496    cap crew crew take edg fickl weather clear con...
# 495    cap bottom cut loos madden crowd search undon ...
# Name: description, dtype: object
# 499    allwear short time simplifi allwear short prov...
# 31     custodian pant long graveyard shift advantag q...
# Name: description, dtype: object
# 499    allwear short time simplifi allwear short prov...
# 33     deliveri short local know best spot deliveri s...
# Name: description, dtype: object
# 499    allwear short time simplifi allwear short prov...
# 461    custodian pant reg graveyard shift advantag qu...
# Name: description, dtype: object
# 499    allwear short time simplifi allwear short prov...
# 462    custodian pant short graveyard shift advantag ...
# Name: description, dtype: object
